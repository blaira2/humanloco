# %%
import humanoid_module as hm
import diffusion as difn
import mujoco
from mujoco import viewer
from stable_baselines3 import PPO, SAC

# %%
default_params = hm.default_params
default_params["TORSO_START_Z"] = hm.compute_start_height(default_params)

hm.generate_xml("humanoid_template.xml", "humanoid_default.xml", **default_params)
# Out:
# Generated: humanoid_default.xml

# %%
model = mujoco.MjModel.from_xml_path("humanoid_custom.xml")
# model = mujoco.MjModel.from_xml_path("humanoid_variant3.xml")
data = mujoco.MjData(model)

viewer.launch(model, data)

# %%
#Train Balance
####################################
from humanoid_variants import VARIANTS
cfg = VARIANTS["test_var"]

xml = cfg["xml"]
model = hm.train_balance_env_sac(
        variant_name="humanoid_custom",
        cfg=cfg,
        xml_file=xml,
        timesteps=1_000_000,   # or more
        parallel_envs=4,
        video_every=250
    )

# %%
#Train Walking
##########################################
from humanoid_variants import VARIANTS
cfg = VARIANTS["test_var"]

xml = cfg["xml"]
starter = SAC.load("humanoid_balance_base.zip")
model = hm.train_variant_sac(
        variant_name="humanoid_custom",
        cfg=cfg,
        xml_file=xml,
        timesteps=2_000_000,   # or more
        parallel_envs=4,
        video_every=200,
        max_episode_steps=2000,
        pretrained_model=starter
    )
# Out:
# Logging to ./logs_humanoid_custom
#
# 🚀 Training SAC for humanoid_custom ...
# [env 3] ep_len=  72 | x_prog=-0.012 | R_mean=-15.097 | fwd= 0.246 | alive=-0.493 | vv_shaping=-0.011 | av_shaping=-0.031 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.041 |contact_p= 8.318 |
# [env 2] ep_len=  81 | x_prog=-0.074 | R_mean=-12.363 | fwd= 0.554 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.012 | com= 0.475 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.003 | energy_p= 0.042 |contact_p= 6.663 |
# [env 0] ep_len=  84 | x_prog= 0.247 | R_mean=-4.548 | fwd= 1.440 | alive=-0.494 | vv_shaping= 0.001 | av_shaping= 0.007 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.003 | energy_p= 0.042 |contact_p= 0.000 |
# [env 1] ep_len=  96 | x_prog=-0.783 | R_mean=-13.907 | fwd= 0.022 | alive=-0.495 | vv_shaping=-0.007 | av_shaping=-0.014 | com= 0.459 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 8.621 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.2     |
# |    ep_rew_mean     | -951     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 4083     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 384      |
# ---------------------------------
# [env 3] ep_len=  93 | x_prog= 0.515 | R_mean=-11.840 | fwd= 2.569 | alive=-0.495 | vv_shaping= 0.000 | av_shaping=-0.002 | com= 0.488 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.007 | energy_p= 0.042 |contact_p= 8.975 |
# [env 2] ep_len=  85 | x_prog=-0.743 | R_mean=-5.847 | fwd= 0.117 | alive=-0.494 | vv_shaping=-0.017 | av_shaping=-0.009 | com= 0.482 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.043 |contact_p= 0.000 |
# [env 0] ep_len=  87 | x_prog= 0.670 | R_mean=-18.740 | fwd= 3.487 | alive=-0.494 | vv_shaping=-0.001 | av_shaping=-0.019 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.006 | energy_p= 0.041 |contact_p= 16.415 |
# [env 1] ep_len=  87 | x_prog= 0.003 | R_mean=-5.279 | fwd= 0.518 | alive=-0.494 | vv_shaping=-0.009 | av_shaping= 0.002 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.042 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.6     |
# |    ep_rew_mean     | -937     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 4107     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 732      |
# ---------------------------------
# [env 0] ep_len=  60 | x_prog=-0.163 | R_mean=-17.485 | fwd= 0.071 | alive=-0.492 | vv_shaping=-0.012 | av_shaping=-0.029 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 9.145 |
# [env 2] ep_len=  70 | x_prog= 0.119 | R_mean=-6.791 | fwd= 1.119 | alive=-0.493 | vv_shaping=-0.011 | av_shaping=-0.003 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.043 |contact_p= 0.707 |
# [env 3] ep_len=  90 | x_prog=-0.822 | R_mean=-8.676 | fwd= 0.087 | alive=-0.494 | vv_shaping=-0.010 | av_shaping=-0.025 | com= 0.464 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.044 |contact_p= 3.097 |
# [env 1] ep_len=  99 | x_prog=-0.604 | R_mean=-14.392 | fwd= 0.062 | alive=-0.495 | vv_shaping=-0.008 | av_shaping=-0.023 | com= 0.460 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 9.295 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.7     |
# |    ep_rew_mean     | -935     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 4120     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1128     |
# ---------------------------------
# [env 0] ep_len=  74 | x_prog=-0.264 | R_mean=-13.812 | fwd= 0.446 | alive=-0.493 | vv_shaping=-0.004 | av_shaping=-0.024 | com= 0.460 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.043 |contact_p= 7.395 |
# [env 2] ep_len=  95 | x_prog=-0.219 | R_mean=-5.397 | fwd= 0.044 | alive=-0.495 | vv_shaping=-0.012 | av_shaping= 0.000 | com= 0.478 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 0.108 |
# [env 3] ep_len=  77 | x_prog=-0.160 | R_mean=-13.337 | fwd= 0.181 | alive=-0.494 | vv_shaping=-0.006 | av_shaping=-0.028 | com= 0.485 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.043 |contact_p= 6.938 |
# [env 1] ep_len=  74 | x_prog= 0.084 | R_mean=-9.201 | fwd= 0.888 | alive=-0.493 | vv_shaping=-0.002 | av_shaping=-0.000 | com= 0.474 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.043 |contact_p= 3.263 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.8     |
# |    ep_rew_mean     | -904     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 4116     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1424     |
# ---------------------------------
# [env 0] ep_len=  68 | x_prog=-0.641 | R_mean=-12.910 | fwd= 0.004 | alive=-0.493 | vv_shaping=-0.006 | av_shaping=-0.014 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 5.502 |
# [env 2] ep_len=  77 | x_prog= 0.185 | R_mean=-13.886 | fwd= 1.231 | alive=-0.494 | vv_shaping=-0.014 | av_shaping=-0.040 | com= 0.491 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.043 |contact_p= 8.520 |
# [env 3] ep_len=  76 | x_prog= 0.138 | R_mean=-17.091 | fwd= 1.146 | alive=-0.493 | vv_shaping=-0.005 | av_shaping=-0.023 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.006 | energy_p= 0.044 |contact_p= 11.584 |
# [env 1] ep_len=  68 | x_prog=-0.526 | R_mean=-10.404 | fwd= 0.017 | alive=-0.493 | vv_shaping=-0.010 | av_shaping=-0.009 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.045 |contact_p= 3.007 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 80.7     |
# |    ep_rew_mean     | -921     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 4146     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1696     |
# ---------------------------------
# [env 0] ep_len=  67 | x_prog=-0.462 | R_mean=-7.548 | fwd= 0.009 | alive=-0.493 | vv_shaping=-0.022 | av_shaping=-0.032 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 0.000 |
# [env 3] ep_len=  83 | x_prog=-0.490 | R_mean=-21.403 | fwd= 0.019 | alive=-0.494 | vv_shaping=-0.001 | av_shaping=-0.005 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.041 |contact_p= 15.350 |
# [env 1] ep_len=  82 | x_prog=-0.578 | R_mean=-8.216 | fwd= 0.164 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.002 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.042 |contact_p= 2.236 |
# [env 2] ep_len= 100 | x_prog=-0.843 | R_mean=-5.032 | fwd= 0.091 | alive=-0.495 | vv_shaping=-0.017 | av_shaping=-0.024 | com= 0.455 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.041 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81       |
# |    ep_rew_mean     | -912     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 4057     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2032     |
# ---------------------------------
# [env 0] ep_len= 104 | x_prog= 0.409 | R_mean=-7.552 | fwd= 1.904 | alive=-0.495 | vv_shaping=-0.006 | av_shaping=-0.027 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.042 |contact_p= 4.573 |
# [env 3] ep_len=  77 | x_prog= 0.116 | R_mean=-5.723 | fwd= 0.847 | alive=-0.494 | vv_shaping=-0.008 | av_shaping=-0.005 | com= 0.477 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.045 |contact_p= 0.000 |
# [env 2] ep_len=  72 | x_prog=-0.548 | R_mean=-22.010 | fwd= 0.133 | alive=-0.493 | vv_shaping=-0.003 | av_shaping=-0.010 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 15.136 |
# [env 1] ep_len=  91 | x_prog= 0.183 | R_mean=-4.560 | fwd= 0.990 | alive=-0.495 | vv_shaping=-0.007 | av_shaping= 0.004 | com= 0.485 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.042 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.8     |
# |    ep_rew_mean     | -897     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 4096     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2388     |
# ---------------------------------
# [env 0] ep_len=  60 | x_prog=-0.504 | R_mean=-9.699 | fwd= 0.000 | alive=-0.492 | vv_shaping=-0.009 | av_shaping=-0.011 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.044 |contact_p= 1.305 |
# [env 2] ep_len=  77 | x_prog=-0.671 | R_mean=-15.550 | fwd= 0.015 | alive=-0.494 | vv_shaping=-0.015 | av_shaping=-0.047 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 8.960 |
# [env 3] ep_len=  98 | x_prog=-0.244 | R_mean=-13.029 | fwd= 0.166 | alive=-0.495 | vv_shaping=-0.005 | av_shaping=-0.018 | com= 0.480 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.043 |contact_p= 8.011 |
# [env 1] ep_len=  82 | x_prog= 0.600 | R_mean=-2.678 | fwd= 3.466 | alive=-0.494 | vv_shaping=-0.008 | av_shaping= 0.005 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.042 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.4     |
# |    ep_rew_mean     | -887     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 4127     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2716     |
# ---------------------------------
# [env 0] ep_len=  98 | x_prog=-0.233 | R_mean=-11.318 | fwd= 0.103 | alive=-0.495 | vv_shaping=-0.007 | av_shaping=-0.021 | com= 0.468 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.041 |contact_p= 6.222 |
# [env 3] ep_len=  83 | x_prog=-0.905 | R_mean=-6.116 | fwd= 0.028 | alive=-0.494 | vv_shaping=-0.020 | av_shaping=-0.031 | com= 0.466 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.041 |contact_p= 0.000 |
# [env 1] ep_len=  87 | x_prog=-0.896 | R_mean=-6.057 | fwd= 0.032 | alive=-0.494 | vv_shaping=-0.016 | av_shaping=-0.014 | com= 0.471 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.044 |contact_p= 0.244 |
# [env 2] ep_len= 111 | x_prog=-0.936 | R_mean=-17.248 | fwd= 0.006 | alive=-0.495 | vv_shaping=-0.002 | av_shaping=-0.005 | com= 0.465 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 12.668 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.9     |
# |    ep_rew_mean     | -901     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 4143     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3072     |
# ---------------------------------
# [env 0] ep_len=  88 | x_prog=-0.786 | R_mean=-9.305 | fwd= 0.064 | alive=-0.494 | vv_shaping=-0.008 | av_shaping=-0.022 | com= 0.479 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.043 |contact_p= 3.598 |
# [env 1] ep_len=  68 | x_prog=-0.318 | R_mean=-9.890 | fwd= 0.014 | alive=-0.493 | vv_shaping=-0.011 | av_shaping=-0.010 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 2.492 |
# [env 2] ep_len=  88 | x_prog= 0.586 | R_mean=-3.013 | fwd= 3.041 | alive=-0.494 | vv_shaping=-0.005 | av_shaping= 0.005 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.042 |contact_p= 0.323 |
# [env 0] ep_len=  84 | x_prog=-1.080 | R_mean=-16.096 | fwd= 0.031 | alive=-0.494 | vv_shaping=-0.001 | av_shaping=-0.006 | com= 0.484 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.041 |contact_p= 10.115 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.8     |
# |    ep_rew_mean     | -889     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 4151     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3496     |
# ---------------------------------
# [env 3] ep_len= 126 | x_prog=-0.385 | R_mean=-7.176 | fwd= 0.080 | alive=-0.496 | vv_shaping=-0.003 | av_shaping=-0.013 | com= 0.457 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.044 |contact_p= 3.188 |
# [env 1] ep_len=  59 | x_prog=-0.674 | R_mean=-38.349 | fwd= 0.003 | alive=-0.492 | vv_shaping=-0.008 | av_shaping=-0.005 | com= 0.485 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.041 |contact_p= 29.817 |
# [env 0] ep_len=  53 | x_prog=-0.486 | R_mean=-11.816 | fwd= 0.014 | alive=-0.491 | vv_shaping=-0.011 | av_shaping=-0.017 | com= 0.489 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.044 |contact_p= 2.324 |
# [env 2] ep_len=  71 | x_prog=-0.032 | R_mean=-6.938 | fwd= 0.189 | alive=-0.493 | vv_shaping=-0.015 | av_shaping=-0.016 | com= 0.484 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.044 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.3     |
# |    ep_rew_mean     | -905     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 4153     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3708     |
# ---------------------------------
# [env 3] ep_len=  88 | x_prog=-0.632 | R_mean=-5.685 | fwd= 0.121 | alive=-0.494 | vv_shaping=-0.018 | av_shaping=-0.017 | com= 0.450 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.045 |contact_p= 0.000 |
# [env 2] ep_len=  72 | x_prog= 0.036 | R_mean=-6.615 | fwd= 0.380 | alive=-0.493 | vv_shaping=-0.010 | av_shaping= 0.006 | com= 0.491 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.043 |contact_p= 0.000 |
# [env 1] ep_len= 109 | x_prog=-0.957 | R_mean=-13.202 | fwd= 0.026 | alive=-0.495 | vv_shaping=-0.004 | av_shaping=-0.010 | com= 0.449 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 8.537 |
# [env 0] ep_len=  83 | x_prog= 0.639 | R_mean=-2.427 | fwd= 3.652 | alive=-0.494 | vv_shaping=-0.006 | av_shaping=-0.006 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.043 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.8     |
# |    ep_rew_mean     | -884     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 4175     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4040     |
# ---------------------------------
# [env 3] ep_len=  76 | x_prog=-0.549 | R_mean=-8.117 | fwd= 0.040 | alive=-0.493 | vv_shaping=-0.015 | av_shaping=-0.027 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 1.499 |
# [env 2] ep_len=  87 | x_prog= 0.001 | R_mean=-14.138 | fwd= 0.614 | alive=-0.494 | vv_shaping=-0.008 | av_shaping=-0.018 | com= 0.490 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.003 | energy_p= 0.043 |contact_p= 8.928 |
# [env 0] ep_len=  90 | x_prog=-0.525 | R_mean=-5.615 | fwd= 0.006 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.009 | com= 0.485 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 0.000 |
# [env 1] ep_len= 114 | x_prog= 0.552 | R_mean=-2.057 | fwd= 2.376 | alive=-0.496 | vv_shaping=-0.003 | av_shaping= 0.006 | com= 0.493 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.043 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.5     |
# |    ep_rew_mean     | -866     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 4173     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4464     |
# ---------------------------------
# [env 3] ep_len=  79 | x_prog=-0.936 | R_mean=-11.926 | fwd= 0.011 | alive=-0.494 | vv_shaping=-0.013 | av_shaping=-0.044 | com= 0.450 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 5.464 |
# [env 2] ep_len=  71 | x_prog=-0.107 | R_mean=-24.264 | fwd= 0.221 | alive=-0.493 | vv_shaping=-0.009 | av_shaping=-0.026 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.042 |contact_p= 17.369 |
# [env 0] ep_len=  78 | x_prog= 0.014 | R_mean=-6.120 | fwd= 0.358 | alive=-0.494 | vv_shaping=-0.010 | av_shaping=-0.001 | com= 0.482 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.044 |contact_p= 0.000 |
# [env 3] ep_len=  99 | x_prog= 0.632 | R_mean=-2.087 | fwd= 3.015 | alive=-0.495 | vv_shaping=-0.006 | av_shaping= 0.006 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.043 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.4     |
# |    ep_rew_mean     | -864     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 4193     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4868     |
# ---------------------------------
# [env 1] ep_len= 112 | x_prog= 0.631 | R_mean=-5.044 | fwd= 2.653 | alive=-0.496 | vv_shaping=-0.004 | av_shaping= 0.006 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.003 | energy_p= 0.044 |contact_p= 3.188 |
# [env 2] ep_len=  90 | x_prog=-0.727 | R_mean=-5.617 | fwd= 0.044 | alive=-0.494 | vv_shaping=-0.018 | av_shaping=-0.030 | com= 0.479 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 0.000 |
# [env 0] ep_len= 104 | x_prog= 0.384 | R_mean=-3.095 | fwd= 1.764 | alive=-0.495 | vv_shaping=-0.001 | av_shaping= 0.004 | com= 0.489 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.042 |contact_p= 0.000 |
# [env 3] ep_len=  66 | x_prog=-0.717 | R_mean=-35.270 | fwd= 0.000 | alive=-0.492 | vv_shaping=-0.003 | av_shaping=-0.010 | com= 0.487 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 27.633 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84       |
# |    ep_rew_mean     | -868     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 4202     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5132     |
# ---------------------------------
# [env 1] ep_len=  80 | x_prog=-0.635 | R_mean=-9.688 | fwd= 0.081 | alive=-0.494 | vv_shaping=-0.010 | av_shaping=-0.025 | com= 0.481 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.041 |contact_p= 3.430 |
# [env 2] ep_len=  87 | x_prog= 0.613 | R_mean=-2.557 | fwd= 3.239 | alive=-0.494 | vv_shaping=-0.004 | av_shaping= 0.003 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.044 |contact_p= 0.000 |
# [env 0] ep_len=  57 | x_prog=-0.476 | R_mean=-10.015 | fwd= 0.012 | alive=-0.491 | vv_shaping=-0.010 | av_shaping=-0.011 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 1.185 |
# [env 3] ep_len=  80 | x_prog=-0.535 | R_mean=-17.435 | fwd= 0.009 | alive=-0.494 | vv_shaping=-0.002 | av_shaping=-0.001 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 11.140 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.5     |
# |    ep_rew_mean     | -860     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 4202     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5452     |
# ---------------------------------
# [env 1] ep_len=  60 | x_prog=-0.520 | R_mean=-10.337 | fwd= 0.015 | alive=-0.492 | vv_shaping=-0.008 | av_shaping=-0.001 | com= 0.477 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 1.950 |
# [env 0] ep_len=  66 | x_prog=-0.508 | R_mean=-8.893 | fwd= 0.027 | alive=-0.492 | vv_shaping=-0.007 | av_shaping=-0.001 | com= 0.483 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 1.284 |
# [env 3] ep_len=  66 | x_prog=-0.183 | R_mean=-7.559 | fwd= 0.092 | alive=-0.492 | vv_shaping=-0.013 | av_shaping=-0.018 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.044 |contact_p= 0.000 |
# [env 2] ep_len= 101 | x_prog= 0.078 | R_mean=-7.711 | fwd= 0.712 | alive=-0.495 | vv_shaping=-0.005 | av_shaping=-0.017 | com= 0.485 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.041 |contact_p= 3.395 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.9     |
# |    ep_rew_mean     | -846     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 4192     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5740     |
# ---------------------------------
# [env 0] ep_len=  71 | x_prog=-0.429 | R_mean=-10.969 | fwd= 0.040 | alive=-0.493 | vv_shaping=-0.014 | av_shaping=-0.023 | com= 0.468 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.041 |contact_p= 3.862 |
# [env 1] ep_len= 130 | x_prog=-1.007 | R_mean=-18.697 | fwd= 0.122 | alive=-0.496 | vv_shaping=-0.002 | av_shaping=-0.011 | com= 0.453 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.044 |contact_p= 14.872 |
# [env 3] ep_len=  86 | x_prog=-0.816 | R_mean=-10.469 | fwd= 0.035 | alive=-0.494 | vv_shaping=-0.011 | av_shaping=-0.033 | com= 0.478 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.040 |contact_p= 4.589 |
# [env 2] ep_len=  96 | x_prog=-0.880 | R_mean=-8.754 | fwd= 0.159 | alive=-0.495 | vv_shaping=-0.011 | av_shaping=-0.017 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.043 |contact_p= 3.635 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.6     |
# |    ep_rew_mean     | -868     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 4190     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6124     |
# ---------------------------------
# [env 0] ep_len=  87 | x_prog=-0.852 | R_mean=-5.795 | fwd= 0.028 | alive=-0.494 | vv_shaping=-0.017 | av_shaping=-0.013 | com= 0.490 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 0.000 |
# [env 1] ep_len=  84 | x_prog=-0.964 | R_mean=-12.675 | fwd= 0.034 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.008 | com= 0.484 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 6.690 |
# [env 3] ep_len=  94 | x_prog= 0.741 | R_mean=-1.735 | fwd= 3.628 | alive=-0.495 | vv_shaping=-0.006 | av_shaping= 0.004 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.042 |contact_p= 0.000 |
# [env 0] ep_len=  66 | x_prog=-0.022 | R_mean=-7.388 | fwd= 0.265 | alive=-0.492 | vv_shaping=-0.016 | av_shaping=-0.020 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.6     |
# |    ep_rew_mean     | -852     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 4203     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6516     |
# ---------------------------------
# [env 2] ep_len=  99 | x_prog= 0.254 | R_mean=-3.824 | fwd= 1.274 | alive=-0.495 | vv_shaping=-0.002 | av_shaping=-0.000 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.044 |contact_p= 0.000 |
# [env 1] ep_len=  53 | x_prog=-0.496 | R_mean=-42.389 | fwd= 0.012 | alive=-0.491 | vv_shaping=-0.007 | av_shaping=-0.024 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 32.897 |
# [env 3] ep_len=  70 | x_prog=-0.425 | R_mean=-7.342 | fwd= 0.021 | alive=-0.493 | vv_shaping=-0.021 | av_shaping=-0.015 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 0.144 |
# [env 0] ep_len=  73 | x_prog= 0.284 | R_mean=-5.026 | fwd= 1.863 | alive=-0.493 | vv_shaping=-0.006 | av_shaping= 0.006 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.003 | energy_p= 0.041 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.1     |
# |    ep_rew_mean     | -853     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 4197     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6808     |
# ---------------------------------
# [env 1] ep_len=  70 | x_prog= 0.348 | R_mean=-4.812 | fwd= 2.375 | alive=-0.493 | vv_shaping=-0.006 | av_shaping= 0.008 | com= 0.493 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.043 |contact_p= 0.000 |
# [env 2] ep_len= 105 | x_prog=-0.234 | R_mean=-7.910 | fwd= 0.252 | alive=-0.495 | vv_shaping=-0.005 | av_shaping=-0.015 | com= 0.474 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.043 |contact_p= 3.315 |
# [env 0] ep_len=  91 | x_prog=-0.930 | R_mean=-14.259 | fwd= 0.017 | alive=-0.495 | vv_shaping=-0.008 | av_shaping=-0.026 | com= 0.475 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 8.686 |
# [env 3] ep_len= 119 | x_prog=-0.086 | R_mean=-4.090 | fwd= 0.175 | alive=-0.496 | vv_shaping=-0.006 | av_shaping= 0.005 | com= 0.475 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.041 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.7     |
# |    ep_rew_mean     | -847     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 4188     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7192     |
# ---------------------------------
# [env 1] ep_len=  95 | x_prog=-1.097 | R_mean=-16.491 | fwd= 0.065 | alive=-0.495 | vv_shaping=-0.000 | av_shaping=-0.005 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.041 |contact_p= 11.249 |
# [env 2] ep_len= 108 | x_prog= 0.460 | R_mean=-2.659 | fwd= 2.025 | alive=-0.495 | vv_shaping=-0.007 | av_shaping= 0.001 | com= 0.491 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.042 |contact_p= 0.000 |
# [env 1] ep_len=  79 | x_prog= 0.001 | R_mean=-6.291 | fwd= 0.329 | alive=-0.494 | vv_shaping=-0.009 | av_shaping= 0.001 | com= 0.481 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.043 |contact_p= 0.226 |
# [env 3] ep_len=  94 | x_prog=-0.972 | R_mean=-7.231 | fwd= 0.006 | alive=-0.495 | vv_shaping=-0.013 | av_shaping=-0.029 | com= 0.483 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 1.822 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.2     |
# |    ep_rew_mean     | -843     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 4180     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7568     |
# ---------------------------------
# [env 0] ep_len= 128 | x_prog=-0.917 | R_mean=-11.153 | fwd= 0.023 | alive=-0.496 | vv_shaping=-0.001 | av_shaping=-0.007 | com= 0.472 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.044 |contact_p= 7.192 |
# [env 2] ep_len=  94 | x_prog=-0.673 | R_mean=-5.187 | fwd= 0.217 | alive=-0.495 | vv_shaping=-0.014 | av_shaping=-0.010 | com= 0.479 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.044 |contact_p= 0.000 |
# [env 1] ep_len=  85 | x_prog= 0.089 | R_mean=-12.148 | fwd= 0.532 | alive=-0.494 | vv_shaping=-0.008 | av_shaping=-0.027 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.003 | energy_p= 0.041 |contact_p= 6.712 |
# [env 3] ep_len=  75 | x_prog=-0.477 | R_mean=-18.615 | fwd= 0.034 | alive=-0.493 | vv_shaping=-0.005 | av_shaping=-0.003 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 11.938 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.7     |
# |    ep_rew_mean     | -854     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 4189     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7868     |
# ---------------------------------
# [env 0] ep_len=  87 | x_prog= 0.800 | R_mean=-17.160 | fwd= 3.918 | alive=-0.494 | vv_shaping=-0.000 | av_shaping=-0.005 | com= 0.483 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.011 | energy_p= 0.043 |contact_p= 15.260 |
# [env 2] ep_len=  74 | x_prog=-0.353 | R_mean=-8.078 | fwd= 0.047 | alive=-0.493 | vv_shaping=-0.013 | av_shaping=-0.017 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 1.299 |
# [env 3] ep_len=  79 | x_prog= 0.049 | R_mean=-15.298 | fwd= 0.677 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.006 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.043 |contact_p= 9.592 |
# [env 1] ep_len=  83 | x_prog=-0.867 | R_mean=-6.063 | fwd= 0.090 | alive=-0.494 | vv_shaping=-0.020 | av_shaping=-0.027 | com= 0.454 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.041 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.5     |
# |    ep_rew_mean     | -858     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 4198     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8188     |
# ---------------------------------
# [env 0] ep_len=  85 | x_prog= 0.679 | R_mean=-2.202 | fwd= 3.724 | alive=-0.494 | vv_shaping=-0.007 | av_shaping= 0.007 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.003 | energy_p= 0.043 |contact_p= 0.000 |
# [env 2] ep_len=  88 | x_prog=-0.770 | R_mean=-11.402 | fwd= 0.052 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.018 | com= 0.457 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.045 |contact_p= 5.666 |
# [env 3] ep_len=  69 | x_prog=-0.194 | R_mean=-8.428 | fwd= 0.064 | alive=-0.493 | vv_shaping=-0.011 | av_shaping= 0.001 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 1.190 |
# [env 0] ep_len=  62 | x_prog=-0.199 | R_mean=-8.136 | fwd= 0.002 | alive=-0.492 | vv_shaping=-0.019 | av_shaping=-0.016 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.044 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.2     |
# |    ep_rew_mean     | -846     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 4207     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8620     |
# ---------------------------------
# [env 1] ep_len= 109 | x_prog= 0.693 | R_mean=-1.689 | fwd= 2.959 | alive=-0.495 | vv_shaping=-0.003 | av_shaping=-0.002 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.003 | energy_p= 0.042 |contact_p= 0.000 |
# [env 2] ep_len=  61 | x_prog=-0.436 | R_mean=-13.863 | fwd= 0.082 | alive=-0.492 | vv_shaping=-0.017 | av_shaping=-0.052 | com= 0.475 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 5.619 |
# [env 3] ep_len=  82 | x_prog=-0.645 | R_mean=-12.822 | fwd= 0.064 | alive=-0.494 | vv_shaping=-0.011 | av_shaping=-0.042 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.041 |contact_p= 6.699 |
# [env 0] ep_len=  75 | x_prog=-0.914 | R_mean=-6.786 | fwd= 0.006 | alive=-0.493 | vv_shaping=-0.021 | av_shaping=-0.023 | com= 0.455 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.1     |
# |    ep_rew_mean     | -834     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 4219     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8920     |
# ---------------------------------
# [env 2] ep_len=  71 | x_prog=-0.269 | R_mean=-15.481 | fwd= 0.013 | alive=-0.493 | vv_shaping=-0.017 | av_shaping=-0.049 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 8.350 |
# [env 1] ep_len=  78 | x_prog= 0.610 | R_mean=-3.023 | fwd= 3.435 | alive=-0.494 | vv_shaping=-0.004 | av_shaping= 0.009 | com= 0.489 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.006 | energy_p= 0.043 |contact_p= 0.000 |
# [env 2] ep_len=  56 | x_prog=-0.537 | R_mean=-11.634 | fwd= 0.026 | alive=-0.491 | vv_shaping=-0.008 | av_shaping=-0.009 | com= 0.481 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.045 |contact_p= 2.661 |
# [env 3] ep_len=  92 | x_prog= 0.402 | R_mean=-3.352 | fwd= 2.127 | alive=-0.495 | vv_shaping=-0.005 | av_shaping= 0.003 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.042 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.5     |
# |    ep_rew_mean     | -820     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 4222     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9156     |
# ---------------------------------
# [env 0] ep_len=  74 | x_prog=-0.329 | R_mean=-19.183 | fwd= 0.150 | alive=-0.493 | vv_shaping=-0.006 | av_shaping=-0.020 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 12.508 |
# [env 1] ep_len=  99 | x_prog= 0.476 | R_mean=-2.875 | fwd= 2.223 | alive=-0.495 | vv_shaping=-0.003 | av_shaping=-0.001 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.003 | energy_p= 0.042 |contact_p= 0.000 |
# [env 3] ep_len=  66 | x_prog=-0.385 | R_mean=-18.080 | fwd= 0.155 | alive=-0.492 | vv_shaping=-0.008 | av_shaping=-0.022 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.043 |contact_p= 10.590 |
# [env 0] ep_len=  76 | x_prog=-0.622 | R_mean=-15.872 | fwd= 0.024 | alive=-0.493 | vv_shaping=-0.007 | av_shaping=-0.029 | com= 0.479 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.043 |contact_p= 9.223 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.5     |
# |    ep_rew_mean     | -824     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 4227     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9520     |
# ---------------------------------
# [env 2] ep_len=  99 | x_prog=-0.816 | R_mean=-8.997 | fwd= 0.147 | alive=-0.495 | vv_shaping=-0.008 | av_shaping=-0.019 | com= 0.455 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.042 |contact_p= 3.982 |
# [env 1] ep_len=  88 | x_prog=-1.026 | R_mean=-8.844 | fwd= 0.019 | alive=-0.494 | vv_shaping=-0.014 | av_shaping=-0.034 | com= 0.463 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.042 |contact_p= 3.060 |
# [env 3] ep_len=  82 | x_prog= 0.327 | R_mean=-4.260 | fwd= 1.888 | alive=-0.494 | vv_shaping=-0.004 | av_shaping=-0.005 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.043 |contact_p= 0.000 |
# [env 0] ep_len=  72 | x_prog=-0.007 | R_mean=-6.648 | fwd= 0.372 | alive=-0.493 | vv_shaping=-0.012 | av_shaping=-0.018 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.043 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.7     |
# |    ep_rew_mean     | -817     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 4235     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9808     |
# ---------------------------------
# [env 2] ep_len= 129 | x_prog= 0.496 | R_mean=-6.580 | fwd= 1.737 | alive=-0.496 | vv_shaping= 0.000 | av_shaping=-0.005 | com= 0.474 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.052 |contact_p= 4.357 |
# [env 1] ep_len= 100 | x_prog=-0.968 | R_mean=-5.090 | fwd= 0.022 | alive=-0.495 | vv_shaping=-0.012 | av_shaping=-0.004 | com= 0.459 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.060 |contact_p= 0.000 |
# [env 0] ep_len=  72 | x_prog=-0.593 | R_mean=-7.006 | fwd= 0.051 | alive=-0.493 | vv_shaping=-0.015 | av_shaping=-0.014 | com= 0.480 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.000 | energy_p= 0.070 |contact_p= 0.000 |
# [env 3] ep_len= 115 | x_prog=-1.303 | R_mean=-8.074 | fwd= 0.089 | alive=-0.496 | vv_shaping=-0.008 | av_shaping=-0.015 | com= 0.474 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.076 |contact_p= 3.694 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85       |
# |    ep_rew_mean     | -805     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 3219     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 10208    |
# | train/             |          |
# |    actor_loss      | 146      |
# |    critic_loss     | 1.11e+04 |
# |    ent_coef        | 0.0109   |
# |    ent_coef_loss   | 473      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 247551   |
# ---------------------------------
# [env 1] ep_len=  81 | x_prog= 0.837 | R_mean=-5.489 | fwd= 4.028 | alive=-0.494 | vv_shaping=-0.016 | av_shaping=-0.019 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.010 | energy_p= 0.108 |contact_p= 3.198 |
# [env 1] ep_len=  89 | x_prog= 0.758 | R_mean=-2.346 | fwd= 3.402 | alive=-0.494 | vv_shaping=-0.010 | av_shaping=-0.002 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.014 | energy_p= 0.108 |contact_p= 0.000 |
# [env 3] ep_len= 153 | x_prog= 0.977 | R_mean=-1.583 | fwd= 2.482 | alive=-0.497 | vv_shaping=-0.005 | av_shaping=-0.002 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.101 |contact_p= 0.686 |
# [env 2] ep_len= 216 | x_prog= 1.118 | R_mean=-13.195 | fwd= 1.883 | alive=-0.498 | vv_shaping= 0.001 | av_shaping= 0.003 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.010 | energy_p= 0.111 |contact_p= 12.648 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.1     |
# |    ep_rew_mean     | -808     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 2079     |
# |    time_elapsed    | 5        |
# |    total_timesteps | 10924    |
# | train/             |          |
# |    actor_loss      | 128      |
# |    critic_loss     | 2.59e+03 |
# |    ent_coef        | 0.0127   |
# |    ent_coef_loss   | 347      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 247730   |
# ---------------------------------
# [env 0] ep_len= 211 | x_prog= 0.532 | R_mean=-15.176 | fwd= 1.343 | alive=-0.498 | vv_shaping= 0.002 | av_shaping= 0.004 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.007 | energy_p= 0.119 |contact_p= 14.031 |
# [env 1] ep_len= 153 | x_prog=-0.950 | R_mean=-5.323 | fwd= 0.191 | alive=-0.497 | vv_shaping=-0.006 | av_shaping=-0.012 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.101 |contact_p= 2.127 |
# [env 2] ep_len= 141 | x_prog=-0.920 | R_mean=-3.547 | fwd= 0.131 | alive=-0.496 | vv_shaping=-0.007 | av_shaping=-0.010 | com= 0.484 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.100 |contact_p= 0.000 |
# [env 0] ep_len= 174 | x_prog=-0.975 | R_mean=-6.933 | fwd= 0.182 | alive=-0.497 | vv_shaping=-0.004 | av_shaping=-0.010 | com= 0.493 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.096 |contact_p= 4.126 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.4     |
# |    ep_rew_mean     | -833     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 1595     |
# |    time_elapsed    | 7        |
# |    total_timesteps | 11636    |
# | train/             |          |
# |    actor_loss      | 127      |
# |    critic_loss     | 1.61e+03 |
# |    ent_coef        | 0.0139   |
# |    ent_coef_loss   | 301      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 247908   |
# ---------------------------------
# [env 3] ep_len= 219 | x_prog=-0.930 | R_mean=-5.169 | fwd= 0.287 | alive=-0.498 | vv_shaping=-0.002 | av_shaping= 0.001 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.098 |contact_p= 3.069 |
# [env 2] ep_len= 125 | x_prog= 1.104 | R_mean=-7.897 | fwd= 2.825 | alive=-0.496 | vv_shaping=-0.008 | av_shaping=-0.010 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.014 | energy_p= 0.105 |contact_p= 6.588 |
# [env 1] ep_len= 172 | x_prog=-1.098 | R_mean=-2.814 | fwd= 0.193 | alive=-0.497 | vv_shaping=-0.006 | av_shaping= 0.003 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.098 |contact_p= 0.000 |
# [env 3] ep_len= 140 | x_prog=-0.851 | R_mean=-3.414 | fwd= 0.262 | alive=-0.496 | vv_shaping=-0.008 | av_shaping=-0.001 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.097 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.8     |
# |    ep_rew_mean     | -831     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 1328     |
# |    time_elapsed    | 9        |
# |    total_timesteps | 12256    |
# | train/             |          |
# |    actor_loss      | 112      |
# |    critic_loss     | 529      |
# |    ent_coef        | 0.0148   |
# |    ent_coef_loss   | 266      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 248063   |
# ---------------------------------
# [env 0] ep_len= 185 | x_prog= 1.140 | R_mean=-3.198 | fwd= 2.000 | alive=-0.497 | vv_shaping=-0.006 | av_shaping=-0.014 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.006 | energy_p= 0.097 |contact_p= 2.375 |
# [env 1] ep_len=  91 | x_prog=-0.943 | R_mean=-5.304 | fwd= 0.310 | alive=-0.495 | vv_shaping=-0.010 | av_shaping= 0.003 | com= 0.487 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.102 |contact_p= 0.000 |
# [env 2] ep_len= 121 | x_prog=-0.977 | R_mean=-3.985 | fwd= 0.252 | alive=-0.496 | vv_shaping=-0.010 | av_shaping=-0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.096 |contact_p= 0.000 |
# [env 3] ep_len= 101 | x_prog=-1.037 | R_mean=-4.879 | fwd= 0.189 | alive=-0.495 | vv_shaping=-0.013 | av_shaping=-0.005 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.099 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95       |
# |    ep_rew_mean     | -811     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 1170     |
# |    time_elapsed    | 10       |
# |    total_timesteps | 12660    |
# | train/             |          |
# |    actor_loss      | 101      |
# |    critic_loss     | 636      |
# |    ent_coef        | 0.0153   |
# |    ent_coef_loss   | 244      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 248164   |
# ---------------------------------
# [env 0] ep_len=  98 | x_prog=-1.055 | R_mean=-5.056 | fwd= 0.163 | alive=-0.495 | vv_shaping=-0.014 | av_shaping=-0.004 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.102 |contact_p= 0.000 |
# [env 1] ep_len=  98 | x_prog=-1.052 | R_mean=-5.043 | fwd= 0.174 | alive=-0.495 | vv_shaping=-0.013 | av_shaping=-0.005 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.100 |contact_p= 0.000 |
# [env 2] ep_len= 129 | x_prog=-1.053 | R_mean=-3.782 | fwd= 0.207 | alive=-0.496 | vv_shaping=-0.010 | av_shaping=-0.004 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.099 |contact_p= 0.000 |
# [env 3] ep_len= 146 | x_prog=-1.042 | R_mean=-3.658 | fwd= 0.129 | alive=-0.497 | vv_shaping=-0.008 | av_shaping=-0.000 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.096 |contact_p= 0.255 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.4     |
# |    ep_rew_mean     | -800     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 1050     |
# |    time_elapsed    | 12       |
# |    total_timesteps | 13244    |
# | train/             |          |
# |    actor_loss      | 99.7     |
# |    critic_loss     | 771      |
# |    ent_coef        | 0.0161   |
# |    ent_coef_loss   | 227      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 248310   |
# ---------------------------------
# [env 1] ep_len= 148 | x_prog=-1.122 | R_mean=-3.338 | fwd= 0.155 | alive=-0.497 | vv_shaping=-0.008 | av_shaping=-0.003 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.097 |contact_p= 0.000 |
# [env 0] ep_len= 212 | x_prog=-1.011 | R_mean=-2.267 | fwd= 0.189 | alive=-0.498 | vv_shaping=-0.006 | av_shaping=-0.001 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.092 |contact_p= 0.000 |
# [env 1] ep_len= 115 | x_prog= 1.051 | R_mean=-5.676 | fwd= 3.193 | alive=-0.496 | vv_shaping=-0.009 | av_shaping= 0.001 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.010 | energy_p= 0.101 |contact_p= 4.407 |
# [env 2] ep_len= 239 | x_prog=-0.952 | R_mean=-2.520 | fwd= 0.229 | alive=-0.498 | vv_shaping=-0.004 | av_shaping= 0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.095 |contact_p= 0.561 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -779     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 942      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 13944    |
# | train/             |          |
# |    actor_loss      | 98.6     |
# |    critic_loss     | 509      |
# |    ent_coef        | 0.017    |
# |    ent_coef_loss   | 200      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 248485   |
# ---------------------------------
# [env 3] ep_len= 177 | x_prog=-1.074 | R_mean=-3.416 | fwd= 0.168 | alive=-0.497 | vv_shaping=-0.005 | av_shaping= 0.001 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.095 |contact_p= 0.661 |
# [env 0] ep_len= 161 | x_prog= 1.094 | R_mean=-0.878 | fwd= 2.352 | alive=-0.497 | vv_shaping=-0.009 | av_shaping=-0.007 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.008 | energy_p= 0.102 |contact_p= 0.000 |
# [env 2] ep_len= 135 | x_prog=-1.268 | R_mean=-5.411 | fwd= 0.159 | alive=-0.496 | vv_shaping=-0.002 | av_shaping= 0.002 | com= 0.491 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.094 |contact_p= 1.764 |
# [env 0] ep_len= 132 | x_prog=-0.837 | R_mean=-3.745 | fwd= 0.164 | alive=-0.496 | vv_shaping=-0.011 | av_shaping=-0.009 | com= 0.493 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.096 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -773     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 841      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 14788    |
# | train/             |          |
# |    actor_loss      | 130      |
# |    critic_loss     | 945      |
# |    ent_coef        | 0.018    |
# |    ent_coef_loss   | 190      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 248696   |
# ---------------------------------
# [env 3] ep_len= 233 | x_prog=-1.167 | R_mean=-2.198 | fwd= 0.107 | alive=-0.498 | vv_shaping=-0.005 | av_shaping=-0.001 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.001 | energy_p= 0.099 |contact_p= 0.051 |
# ...
# [env 2] ep_len= 114 | x_prog= 1.116 | R_mean=-0.361 | fwd= 4.127 | alive=-0.496 | vv_shaping=-0.012 | av_shaping=-0.007 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.082 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 134      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 1168     |
# |    fps             | 330      |
# |    time_elapsed    | 625      |
# |    total_timesteps | 206932   |
# | train/             |          |
# |    actor_loss      | 276      |
# |    critic_loss     | 403      |
# |    ent_coef        | 0.0384   |
# |    ent_coef_loss   | -0.884   |
# |    learning_rate   | 0.000269 |
# |    n_updates       | 296732   |
# ---------------------------------
# [env 3] ep_len= 528 | x_prog= 1.105 | R_mean=-1.166 | fwd= 0.960 | alive=-0.499 | vv_shaping=-0.001 | av_shaping= 0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.072 |contact_p= 1.107 |
# [env 1] ep_len=  87 | x_prog= 0.958 | R_mean=-1.486 | fwd= 4.369 | alive=-0.494 | vv_shaping=-0.017 | av_shaping=-0.014 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.008 | energy_p= 0.074 |contact_p= 0.000 |
# [env 0] ep_len= 106 | x_prog= 1.127 | R_mean=-0.408 | fwd= 4.398 | alive=-0.495 | vv_shaping=-0.006 | av_shaping=-0.007 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.075 |contact_p= 0.000 |
# [env 3] ep_len= 115 | x_prog= 1.109 | R_mean=-1.235 | fwd= 3.688 | alive=-0.496 | vv_shaping=-0.009 | av_shaping= 0.001 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.006 | energy_p= 0.079 |contact_p= 0.485 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -109     |
# | time/              |          |
# |    episodes        | 1172     |
# |    fps             | 330      |
# |    time_elapsed    | 627      |
# |    total_timesteps | 207596   |
# | train/             |          |
# |    actor_loss      | 296      |
# |    critic_loss     | 496      |
# |    ent_coef        | 0.0389   |
# |    ent_coef_loss   | 7.7      |
# |    learning_rate   | 0.000269 |
# |    n_updates       | 296898   |
# ---------------------------------
# [env 2] ep_len= 172 | x_prog= 1.308 | R_mean= 0.189 | fwd= 3.186 | alive=-0.497 | vv_shaping=-0.006 | av_shaping=-0.005 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.006 | energy_p= 0.076 |contact_p= 0.000 |
# [env 1] ep_len= 119 | x_prog= 1.123 | R_mean=-1.533 | fwd= 3.697 | alive=-0.496 | vv_shaping=-0.009 | av_shaping=-0.006 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.075 |contact_p= 0.937 |
# [env 0] ep_len= 105 | x_prog= 1.079 | R_mean=-1.960 | fwd= 4.046 | alive=-0.495 | vv_shaping=-0.010 | av_shaping=-0.001 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.006 | energy_p= 0.074 |contact_p= 1.153 |
# [env 0] ep_len=  98 | x_prog= 1.216 | R_mean=-0.670 | fwd= 4.526 | alive=-0.495 | vv_shaping=-0.011 | av_shaping=-0.005 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.078 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 1176     |
# |    fps             | 330      |
# |    time_elapsed    | 629      |
# |    total_timesteps | 208148   |
# | train/             |          |
# |    actor_loss      | 270      |
# |    critic_loss     | 395      |
# |    ent_coef        | 0.0392   |
# |    ent_coef_loss   | 2.11     |
# |    learning_rate   | 0.000269 |
# |    n_updates       | 297036   |
# ---------------------------------
# [env 2] ep_len= 163 | x_prog= 1.423 | R_mean=-0.193 | fwd= 3.716 | alive=-0.497 | vv_shaping=-0.005 | av_shaping= 0.001 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.081 |contact_p= 0.753 |
# [env 3] ep_len= 175 | x_prog= 1.223 | R_mean=-0.428 | fwd= 2.529 | alive=-0.497 | vv_shaping=-0.008 | av_shaping=-0.009 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.076 |contact_p= 0.000 |
# [env 1] ep_len= 158 | x_prog= 0.896 | R_mean=-0.911 | fwd= 2.347 | alive=-0.497 | vv_shaping=-0.007 | av_shaping=-0.000 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.008 | energy_p= 0.077 |contact_p= 0.000 |
# [env 0] ep_len=  93 | x_prog= 1.110 | R_mean=-4.215 | fwd= 4.230 | alive=-0.495 | vv_shaping=-0.016 | av_shaping=-0.015 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.009 | energy_p= 0.082 |contact_p= 2.951 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -114     |
# | time/              |          |
# |    episodes        | 1180     |
# |    fps             | 330      |
# |    time_elapsed    | 630      |
# |    total_timesteps | 208520   |
# | train/             |          |
# |    actor_loss      | 279      |
# |    critic_loss     | 354      |
# |    ent_coef        | 0.0392   |
# |    ent_coef_loss   | -0.726   |
# |    learning_rate   | 0.000269 |
# |    n_updates       | 297129   |
# ---------------------------------
# [env 3] ep_len=  99 | x_prog= 1.067 | R_mean=-1.360 | fwd= 3.808 | alive=-0.495 | vv_shaping=-0.015 | av_shaping=-0.017 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.009 | energy_p= 0.080 |contact_p= 0.000 |
# [env 1] ep_len= 110 | x_prog= 0.649 | R_mean=-1.823 | fwd= 2.812 | alive=-0.495 | vv_shaping=-0.009 | av_shaping= 0.003 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.007 | energy_p= 0.081 |contact_p= 0.000 |
# [env 2] ep_len= 135 | x_prog= 0.499 | R_mean=-2.017 | fwd= 1.763 | alive=-0.496 | vv_shaping=-0.005 | av_shaping= 0.001 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.074 |contact_p= 0.000 |
# [env 0] ep_len= 100 | x_prog= 1.173 | R_mean=-0.613 | fwd= 4.492 | alive=-0.495 | vv_shaping=-0.010 | av_shaping=-0.011 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.006 | energy_p= 0.083 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 1184     |
# |    fps             | 330      |
# |    time_elapsed    | 632      |
# |    total_timesteps | 208920   |
# | train/             |          |
# |    actor_loss      | 266      |
# |    critic_loss     | 218      |
# |    ent_coef        | 0.0394   |
# |    ent_coef_loss   | -2.98    |
# |    learning_rate   | 0.000269 |
# |    n_updates       | 297229   |
# ---------------------------------
# [env 3] ep_len=  86 | x_prog= 1.052 | R_mean=-1.208 | fwd= 4.721 | alive=-0.494 | vv_shaping=-0.016 | av_shaping=-0.015 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.011 | energy_p= 0.080 |contact_p= 0.000 |
# [env 2] ep_len= 104 | x_prog= 1.208 | R_mean=-0.663 | fwd= 4.255 | alive=-0.495 | vv_shaping=-0.014 | av_shaping=-0.017 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.008 | energy_p= 0.077 |contact_p= 0.000 |
# [env 1] ep_len= 163 | x_prog= 1.473 | R_mean= 0.444 | fwd= 3.602 | alive=-0.497 | vv_shaping=-0.007 | av_shaping=-0.005 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.077 |contact_p= 0.000 |
# [env 0] ep_len= 158 | x_prog= 0.333 | R_mean=-5.406 | fwd= 1.181 | alive=-0.497 | vv_shaping= 0.002 | av_shaping=-0.002 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.005 | energy_p= 0.079 |contact_p= 3.341 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 1188     |
# |    fps             | 330      |
# |    time_elapsed    | 634      |
# |    total_timesteps | 209552   |
# | train/             |          |
# |    actor_loss      | 285      |
# |    critic_loss     | 306      |
# |    ent_coef        | 0.0394   |
# |    ent_coef_loss   | 2.05     |
# |    learning_rate   | 0.000269 |
# |    n_updates       | 297387   |
# ---------------------------------
# [env 2] ep_len= 104 | x_prog= 1.068 | R_mean=-1.111 | fwd= 3.806 | alive=-0.495 | vv_shaping=-0.014 | av_shaping=-0.010 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.007 | energy_p= 0.081 |contact_p= 0.000 |
# [env 1] ep_len= 152 | x_prog= 0.883 | R_mean=-3.980 | fwd= 2.750 | alive=-0.497 | vv_shaping=-0.008 | av_shaping=-0.004 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.078 |contact_p= 3.348 |
# [env 0] ep_len= 130 | x_prog= 1.032 | R_mean=-0.933 | fwd= 3.019 | alive=-0.496 | vv_shaping=-0.011 | av_shaping=-0.015 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.007 | energy_p= 0.078 |contact_p= 0.000 |
# [env 2] ep_len= 116 | x_prog= 0.941 | R_mean=-0.679 | fwd= 3.735 | alive=-0.496 | vv_shaping=-0.013 | av_shaping=-0.011 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.079 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 135      |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 1192     |
# |    fps             | 330      |
# |    time_elapsed    | 635      |
# |    total_timesteps | 210108   |
# | train/             |          |
# |    actor_loss      | 278      |
# |    critic_loss     | 409      |
# |    ent_coef        | 0.0393   |
# |    ent_coef_loss   | 1.44     |
# |    learning_rate   | 0.000268 |
# |    n_updates       | 297526   |
# ---------------------------------
# [env 0] ep_len= 101 | x_prog= 1.131 | R_mean=-1.851 | fwd= 4.446 | alive=-0.495 | vv_shaping=-0.012 | av_shaping=-0.004 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.006 | energy_p= 0.077 |contact_p= 1.252 |
# [env 1] ep_len= 141 | x_prog= 0.503 | R_mean=-1.785 | fwd= 1.838 | alive=-0.496 | vv_shaping=-0.004 | av_shaping= 0.001 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.074 |contact_p= 0.000 |
# [env 2] ep_len= 141 | x_prog= 1.418 | R_mean=-0.666 | fwd= 4.188 | alive=-0.496 | vv_shaping=-0.009 | av_shaping=-0.003 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.004 | energy_p= 0.081 |contact_p= 1.210 |
# [env 0] ep_len=  93 | x_prog= 1.129 | R_mean=-1.172 | fwd= 4.321 | alive=-0.495 | vv_shaping=-0.016 | av_shaping=-0.013 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.009 | energy_p= 0.082 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 134      |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    episodes        | 1196     |
# |    fps             | 330      |
# |    time_elapsed    | 638      |
# |    total_timesteps | 210848   |
# | train/             |          |
# |    actor_loss      | 256      |
# |    critic_loss     | 393      |
# |    ent_coef        | 0.0394   |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.000268 |
# |    n_updates       | 297711   |
# ---------------------------------
# [env 2] ep_len=  77 | x_prog= 1.140 | R_mean=-5.831 | fwd= 5.372 | alive=-0.494 | vv_shaping=-0.010 | av_shaping=-0.007 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.007 | energy_p= 0.081 |contact_p= 4.612 |
# [env 1] ep_len= 144 | x_prog= 0.929 | R_mean=-0.539 | fwd= 3.028 | alive=-0.497 | vv_shaping=-0.010 | av_shaping=-0.004 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.002 | energy_p= 0.081 |contact_p= 0.000 |
# [env 0] ep_len= 130 | x_prog= 1.156 | R_mean= 0.003 | fwd= 3.944 | alive=-0.496 | vv_shaping=-0.010 | av_shaping=-0.004 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.008 | energy_p= 0.077 |contact_p= 0.000 |
# calculated base height: 1.0799999999999998
# MoviePy - Building video C:\Users\Lep\OneDrive\Documents\Course Work\CS 535 Machine Learning\Human Project\humanoid_custom_videos\ep_1200\ep_1200-step-0-to-step-1000.mp4.
# MoviePy - Writing video C:\Users\Lep\OneDrive\Documents\Course Work\CS 535 Machine Learning\Human Project\humanoid_custom_videos\ep_1200\ep_1200-step-0-to-step-1000.mp4
# MoviePy - Done !
# MoviePy - video ready C:\Users\Lep\OneDrive\Documents\Course Work\CS 535 Machine Learning\Human Project\humanoid_custom_videos\ep_1200\ep_1200-step-0-to-step-1000.mp4
# [🎥] Saved video at episode 1200 → humanoid_custom_videos\ep_1200
# [env 2] ep_len=  99 | x_prog= 1.058 | R_mean=-1.116 | fwd= 4.040 | alive=-0.495 | vv_shaping=-0.014 | av_shaping=-0.006 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | vel_stab_p= 0.006 | energy_p= 0.083 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -125     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 329      |
# |    time_elapsed    | 640      |
# |    total_timesteps | 211376   |
# | train/             |          |
# |    actor_loss      | 271      |
# |    critic_loss     | 413      |
# |    ent_coef        | 0.0391   |
# |    ent_coef_loss   | -3.47    |
# |    learning_rate   | 0.000268 |
# |    n_updates       | 297843   |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       6 xml = cfg["xml"]
#       7 starter = SAC.load("humanoid_balance_base.zip")
# ----> 8 model = hm.train_variant_sac(
#       9         variant_name="humanoid_custom",
#      10         cfg=cfg,
#      11         xml_file=xml,
#      12         timesteps=2_000_000,   # or more
#      13         parallel_envs=4,
#      14         video_every=200,
#      15         max_episode_steps=2000,
#      16         pretrained_model=starter
#      17     )
#
# File ~\OneDrive\Documents\Course Work\CS 535 Machine Learning\Human Project\humanoid_module.py:504, in train_variant_sac(variant_name, cfg, xml_file, timesteps, parallel_envs, initial_learning_rate, video_every, max_episode_steps, pretrained_model)
#     502 # ---------- TRAIN ----------
#     503 print(f"\n🚀 Training SAC for {variant_name} ...")
# --> 504 model.learn(total_timesteps=timesteps, callback=[video_cb, debug_cb])
#     506 # ---------- SAVE ----------
#     507 model.save(f"{variant_name}_sac.zip")
#
# File ~\miniconda3\Lib\site-packages\stable_baselines3\sac\sac.py:313, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     304 def learn(
#     305     self: SelfSAC,
#     306     total_timesteps: int,
#    (...)    311     progress_bar: bool = False,
#     312 ) -> SelfSAC:
# --> 313     return super().learn(
#     314         total_timesteps=total_timesteps,
#     315         callback=callback,
#     316         log_interval=log_interval,
#     317         tb_log_name=tb_log_name,
#     318         reset_num_timesteps=reset_num_timesteps,
#     319         progress_bar=progress_bar,
#     320     )
#
# File ~\miniconda3\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:354, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     352         # Special case when the user passes `gradient_steps=0`
#     353         if gradient_steps > 0:
# --> 354             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     356 callback.on_training_end()
#     358 return self
#
# File ~\miniconda3\Lib\site-packages\stable_baselines3\sac\sac.py:237, in SAC.train(self, gradient_steps, batch_size)
#     235     ent_coef = th.exp(self.log_ent_coef.detach())
#     236     assert isinstance(self.target_entropy, float)
# --> 237     ent_coef_loss = -(self.log_ent_coef * (log_prob + self.target_entropy).detach()).mean()
#     238     ent_coef_losses.append(ent_coef_loss.item())
#     239 else:
#
# KeyboardInterrupt:

# %%
#Generate More Video Samples
######
from humanoid_variants import VARIANTS
cfg = VARIANTS["test_var"]

model = SAC.load("humanoid_custom_sac.zip")

hm.record_policy_video(
    model, 
    variant_name="humanoid_custom", 
    cfg=cfg, 
    video_dir="test_videos", 
    num_episodes=3
)


######
# Out:
# calculated base height: 1.0799999999999998
# [video] Loaded VecNormalize stats from ./norms/humanoid_custom_vecnorm.pkl
# Saved videos to: test_videos

# %%
#Collect trajectories
from humanoid_module import VARIANTS
cfg = VARIANTS["default_var"]

model = PPO.load("humanoid_default_ppo.zip")
hm.collect_trajectories(
        model=model,
        variant_name="humanoid_default",
        cfg=cfg,
        num_episodes=20
    )
# Out:
# Saved: humanoid_default_traj.npz

# %%
#build diffusion
import numpy as np
import torch
from torch.utils.data import DataLoader
from diffusion import HumanoidDiffusionDataset, PoseDiffusion, morph_vector_from_params
from humanoid_module import VARIANTS

def build_diffusion_dataset(traj_files, past_len=10, future_len=10):
    episodes = []
    for name, cfg in VARIANTS.items():
        file = f"{name}_traj.npz"
        if file not in traj_files:
            continue
        data = np.load(file)
        qpos = data["qpos"]  # [T, D_q]
        morph_vec = morph_vector_from_params(cfg)  # uses MORPH_KEYS in diffusion.py
        episodes.append({"qpos": qpos, "morph": morph_vec})

    dataset = HumanoidDiffusionDataset(
        episodes=episodes,
        past_len=past_len,
        future_len=future_len
    )
    return dataset

traj_files = [f"{name}_traj.npz" for name in VARIANTS.keys()]
dataset = build_diffusion_dataset(traj_files, past_len=10, future_len=10)
loader = DataLoader(dataset, batch_size=64, shuffle=True)

# %%
#Train diffusion

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

diffusion_model = PoseDiffusion(
    D_target=dataset.D_target,
    D_cond=dataset.D_cond,
    n_steps=100,
    hidden=512
).to(device)

opt = torch.optim.Adam(diffusion_model.parameters(), lr=1e-4)

def train_diffusion(num_epochs=20):
    diffusion_model.train()
    for epoch in range(num_epochs):
        total_loss = 0.0
        for x_0, cond in loader:
            x_0 = x_0.to(device)      # future pose chunk flattened
            cond = cond.to(device)    # past poses + morphology

            B = x_0.size(0)
            t = torch.randint(
                0, diffusion_model.n_steps,
                (B,), device=device, dtype=torch.long
            )
            noise = torch.randn_like(x_0)
            x_t = diffusion_model.q_sample(x_0, t, noise=noise)

            eps_pred = diffusion_model(x_t, t, cond)
            loss = torch.mean((eps_pred - noise) ** 2)

            opt.zero_grad()
            loss.backward()
            opt.step()

            total_loss += loss.item() * B

        print(f"Epoch {epoch+1}: loss = {total_loss / len(dataset):.6f}")

    torch.save(diffusion_model.state_dict(), "pose_diffusion.pt")

train_diffusion()
