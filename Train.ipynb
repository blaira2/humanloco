# %%
import humanoid_module as hm
import diffusion as difn
import mujoco
from mujoco import viewer
from stable_baselines3 import PPO, SAC

# %%
default_params = hm.default_params
default_params["TORSO_START_Z"] = hm.compute_start_height(default_params)

hm.generate_xml("humanoid_template.xml", "humanoid_default.xml", **default_params)
# Out:
# Generated: humanoid_default.xml

# %%
model = mujoco.MjModel.from_xml_path("humanoid_custom.xml")
# model = mujoco.MjModel.from_xml_path("humanoid_variant3.xml")
data = mujoco.MjData(model)

viewer.launch(model, data)

# %%
#Train Balance
####################################
from humanoid_variants import VARIANTS
cfg = VARIANTS["test_var"]

xml = cfg["xml"]
model = hm.train_balance_env_sac(
        variant_name="humanoid_custom",
        cfg=cfg,
        xml_file=xml,
        timesteps=1_000_000,   # or more
        parallel_envs=4,
        video_every=250
    )

# %%
#Train Walking
##########################################
from humanoid_variants import VARIANTS
cfg = VARIANTS["test_var"]

xml = cfg["xml"]
starter = SAC.load("humanoid_balance_base.zip")
model = hm.train_variant_sac(
        variant_name="humanoid_custom",
        cfg=cfg,
        xml_file=xml,
        timesteps=2_000_000,   # or more
        parallel_envs=4,
        video_every=200,
        max_episode_steps=2000,
        pretrained_model=starter
    )
# Out:
# Logging to ./logs_humanoid_custom
#
# 🚀 Training SAC for humanoid_custom ...
# [env 3] ep_len=  72 | x_prog=-0.012 | R_mean=-15.148 | fwd= 0.246 | alive=-0.493 | vv_shaping=-0.011 | av_shaping=-0.031 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.052 | energy_p= 0.041 |contact_p= 8.318 |
# [env 2] ep_len=  81 | x_prog=-0.074 | R_mean=-12.410 | fwd= 0.554 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.012 | com= 0.475 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.051 | energy_p= 0.042 |contact_p= 6.663 |
# [env 0] ep_len=  84 | x_prog= 0.247 | R_mean=-4.584 | fwd= 1.440 | alive=-0.494 | vv_shaping= 0.001 | av_shaping= 0.007 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.042 |contact_p= 0.000 |
# [env 1] ep_len=  96 | x_prog=-0.783 | R_mean=-13.955 | fwd= 0.022 | alive=-0.495 | vv_shaping=-0.007 | av_shaping=-0.014 | com= 0.459 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.048 | energy_p= 0.043 |contact_p= 8.621 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.2     |
# |    ep_rew_mean     | -955     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 4281     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 384      |
# ---------------------------------
# [env 3] ep_len=  93 | x_prog= 0.515 | R_mean=-11.885 | fwd= 2.569 | alive=-0.495 | vv_shaping= 0.000 | av_shaping=-0.002 | com= 0.488 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.052 | energy_p= 0.042 |contact_p= 8.975 |
# [env 2] ep_len=  85 | x_prog=-0.743 | R_mean=-5.888 | fwd= 0.117 | alive=-0.494 | vv_shaping=-0.017 | av_shaping=-0.009 | com= 0.482 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.042 | energy_p= 0.043 |contact_p= 0.000 |
# [env 0] ep_len=  87 | x_prog= 0.670 | R_mean=-18.781 | fwd= 3.487 | alive=-0.494 | vv_shaping=-0.001 | av_shaping=-0.019 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.041 |contact_p= 16.415 |
# [env 1] ep_len=  87 | x_prog= 0.003 | R_mean=-5.319 | fwd= 0.518 | alive=-0.494 | vv_shaping=-0.009 | av_shaping= 0.002 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.041 | energy_p= 0.042 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.6     |
# |    ep_rew_mean     | -940     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 4213     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 732      |
# ---------------------------------
# [env 0] ep_len=  60 | x_prog=-0.163 | R_mean=-17.545 | fwd= 0.071 | alive=-0.492 | vv_shaping=-0.012 | av_shaping=-0.029 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.060 | energy_p= 0.043 |contact_p= 9.145 |
# [env 2] ep_len=  70 | x_prog= 0.119 | R_mean=-6.834 | fwd= 1.119 | alive=-0.493 | vv_shaping=-0.011 | av_shaping=-0.003 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.043 |contact_p= 0.707 |
# [env 3] ep_len=  90 | x_prog=-0.822 | R_mean=-8.718 | fwd= 0.087 | alive=-0.494 | vv_shaping=-0.010 | av_shaping=-0.025 | com= 0.464 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.043 | energy_p= 0.044 |contact_p= 3.097 |
# [env 1] ep_len=  99 | x_prog=-0.604 | R_mean=-14.439 | fwd= 0.062 | alive=-0.495 | vv_shaping=-0.008 | av_shaping=-0.023 | com= 0.460 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.042 |contact_p= 9.295 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.7     |
# |    ep_rew_mean     | -939     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 4277     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1128     |
# ---------------------------------
# [env 0] ep_len=  74 | x_prog=-0.264 | R_mean=-13.860 | fwd= 0.446 | alive=-0.493 | vv_shaping=-0.004 | av_shaping=-0.024 | com= 0.460 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.050 | energy_p= 0.043 |contact_p= 7.395 |
# [env 2] ep_len=  95 | x_prog=-0.219 | R_mean=-5.438 | fwd= 0.044 | alive=-0.495 | vv_shaping=-0.012 | av_shaping= 0.000 | com= 0.478 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.041 | energy_p= 0.042 |contact_p= 0.108 |
# [env 3] ep_len=  77 | x_prog=-0.160 | R_mean=-13.383 | fwd= 0.181 | alive=-0.494 | vv_shaping=-0.006 | av_shaping=-0.028 | com= 0.485 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.043 |contact_p= 6.938 |
# [env 1] ep_len=  74 | x_prog= 0.084 | R_mean=-9.240 | fwd= 0.888 | alive=-0.493 | vv_shaping=-0.002 | av_shaping=-0.000 | com= 0.474 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.043 | energy_p= 0.043 |contact_p= 3.263 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.8     |
# |    ep_rew_mean     | -908     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 4291     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1424     |
# ---------------------------------
# [env 0] ep_len=  68 | x_prog=-0.641 | R_mean=-12.966 | fwd= 0.004 | alive=-0.493 | vv_shaping=-0.006 | av_shaping=-0.014 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.056 | energy_p= 0.043 |contact_p= 5.502 |
# [env 2] ep_len=  77 | x_prog= 0.185 | R_mean=-13.937 | fwd= 1.231 | alive=-0.494 | vv_shaping=-0.014 | av_shaping=-0.040 | com= 0.491 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.055 | energy_p= 0.043 |contact_p= 8.520 |
# [env 3] ep_len=  76 | x_prog= 0.138 | R_mean=-17.137 | fwd= 1.146 | alive=-0.493 | vv_shaping=-0.005 | av_shaping=-0.023 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.051 | energy_p= 0.044 |contact_p= 11.584 |
# [env 1] ep_len=  68 | x_prog=-0.526 | R_mean=-10.462 | fwd= 0.017 | alive=-0.493 | vv_shaping=-0.010 | av_shaping=-0.009 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.058 | energy_p= 0.045 |contact_p= 3.007 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 80.7     |
# |    ep_rew_mean     | -925     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 4296     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1696     |
# ---------------------------------
# [env 0] ep_len=  67 | x_prog=-0.462 | R_mean=-7.601 | fwd= 0.009 | alive=-0.493 | vv_shaping=-0.022 | av_shaping=-0.032 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.053 | energy_p= 0.043 |contact_p= 0.000 |
# [env 3] ep_len=  83 | x_prog=-0.490 | R_mean=-21.455 | fwd= 0.019 | alive=-0.494 | vv_shaping=-0.001 | av_shaping=-0.005 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.052 | energy_p= 0.041 |contact_p= 15.350 |
# [env 1] ep_len=  82 | x_prog=-0.578 | R_mean=-8.262 | fwd= 0.164 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.002 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.048 | energy_p= 0.042 |contact_p= 2.236 |
# [env 2] ep_len= 100 | x_prog=-0.843 | R_mean=-5.072 | fwd= 0.091 | alive=-0.495 | vv_shaping=-0.017 | av_shaping=-0.024 | com= 0.455 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.040 | energy_p= 0.041 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81       |
# |    ep_rew_mean     | -915     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 4286     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2032     |
# ---------------------------------
# [env 0] ep_len= 104 | x_prog= 0.409 | R_mean=-7.591 | fwd= 1.904 | alive=-0.495 | vv_shaping=-0.006 | av_shaping=-0.027 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.041 | energy_p= 0.042 |contact_p= 4.573 |
# [env 3] ep_len=  77 | x_prog= 0.116 | R_mean=-5.765 | fwd= 0.847 | alive=-0.494 | vv_shaping=-0.008 | av_shaping=-0.005 | com= 0.477 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.045 |contact_p= 0.000 |
# [env 2] ep_len=  72 | x_prog=-0.548 | R_mean=-22.061 | fwd= 0.133 | alive=-0.493 | vv_shaping=-0.003 | av_shaping=-0.010 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.051 | energy_p= 0.043 |contact_p= 15.136 |
# [env 1] ep_len=  91 | x_prog= 0.183 | R_mean=-4.600 | fwd= 0.990 | alive=-0.495 | vv_shaping=-0.007 | av_shaping= 0.004 | com= 0.485 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.042 | energy_p= 0.042 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.8     |
# |    ep_rew_mean     | -900     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 4300     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2388     |
# ---------------------------------
# [env 0] ep_len=  60 | x_prog=-0.504 | R_mean=-9.755 | fwd= 0.000 | alive=-0.492 | vv_shaping=-0.009 | av_shaping=-0.011 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.056 | energy_p= 0.044 |contact_p= 1.305 |
# [env 2] ep_len=  77 | x_prog=-0.671 | R_mean=-15.597 | fwd= 0.015 | alive=-0.494 | vv_shaping=-0.015 | av_shaping=-0.047 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.042 |contact_p= 8.960 |
# [env 3] ep_len=  98 | x_prog=-0.244 | R_mean=-13.072 | fwd= 0.166 | alive=-0.495 | vv_shaping=-0.005 | av_shaping=-0.018 | com= 0.480 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.045 | energy_p= 0.043 |contact_p= 8.011 |
# [env 1] ep_len=  82 | x_prog= 0.600 | R_mean=-2.712 | fwd= 3.466 | alive=-0.494 | vv_shaping=-0.008 | av_shaping= 0.005 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.042 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.4     |
# |    ep_rew_mean     | -891     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 4287     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2716     |
# ---------------------------------
# [env 0] ep_len=  98 | x_prog=-0.233 | R_mean=-11.364 | fwd= 0.103 | alive=-0.495 | vv_shaping=-0.007 | av_shaping=-0.021 | com= 0.468 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.041 |contact_p= 6.222 |
# [env 3] ep_len=  83 | x_prog=-0.905 | R_mean=-6.160 | fwd= 0.028 | alive=-0.494 | vv_shaping=-0.020 | av_shaping=-0.031 | com= 0.466 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.041 |contact_p= 0.000 |
# [env 1] ep_len=  87 | x_prog=-0.896 | R_mean=-6.096 | fwd= 0.032 | alive=-0.494 | vv_shaping=-0.016 | av_shaping=-0.014 | com= 0.471 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.040 | energy_p= 0.044 |contact_p= 0.244 |
# [env 2] ep_len= 111 | x_prog=-0.936 | R_mean=-17.297 | fwd= 0.006 | alive=-0.495 | vv_shaping=-0.002 | av_shaping=-0.005 | com= 0.465 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.049 | energy_p= 0.043 |contact_p= 12.668 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.9     |
# |    ep_rew_mean     | -905     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 4297     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3072     |
# ---------------------------------
# [env 0] ep_len=  88 | x_prog=-0.786 | R_mean=-9.351 | fwd= 0.064 | alive=-0.494 | vv_shaping=-0.008 | av_shaping=-0.022 | com= 0.479 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.043 |contact_p= 3.598 |
# [env 1] ep_len=  68 | x_prog=-0.318 | R_mean=-9.940 | fwd= 0.014 | alive=-0.493 | vv_shaping=-0.011 | av_shaping=-0.010 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.050 | energy_p= 0.043 |contact_p= 2.492 |
# [env 2] ep_len=  88 | x_prog= 0.586 | R_mean=-3.048 | fwd= 3.041 | alive=-0.494 | vv_shaping=-0.005 | av_shaping= 0.005 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.040 | energy_p= 0.042 |contact_p= 0.323 |
# [env 0] ep_len=  84 | x_prog=-1.080 | R_mean=-16.148 | fwd= 0.031 | alive=-0.494 | vv_shaping=-0.001 | av_shaping=-0.006 | com= 0.484 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.052 | energy_p= 0.041 |contact_p= 10.115 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.8     |
# |    ep_rew_mean     | -892     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 4302     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3496     |
# ---------------------------------
# [env 3] ep_len= 126 | x_prog=-0.385 | R_mean=-7.218 | fwd= 0.080 | alive=-0.496 | vv_shaping=-0.003 | av_shaping=-0.013 | com= 0.457 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.042 | energy_p= 0.044 |contact_p= 3.188 |
# [env 1] ep_len=  59 | x_prog=-0.674 | R_mean=-38.410 | fwd= 0.003 | alive=-0.492 | vv_shaping=-0.008 | av_shaping=-0.005 | com= 0.485 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.061 | energy_p= 0.041 |contact_p= 29.817 |
# [env 0] ep_len=  53 | x_prog=-0.486 | R_mean=-11.864 | fwd= 0.014 | alive=-0.491 | vv_shaping=-0.011 | av_shaping=-0.017 | com= 0.489 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.048 | energy_p= 0.044 |contact_p= 2.324 |
# [env 2] ep_len=  71 | x_prog=-0.032 | R_mean=-6.988 | fwd= 0.189 | alive=-0.493 | vv_shaping=-0.015 | av_shaping=-0.016 | com= 0.484 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.051 | energy_p= 0.044 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.3     |
# |    ep_rew_mean     | -909     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 4298     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3708     |
# ---------------------------------
# [env 3] ep_len=  88 | x_prog=-0.632 | R_mean=-5.728 | fwd= 0.121 | alive=-0.494 | vv_shaping=-0.018 | av_shaping=-0.017 | com= 0.450 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.043 | energy_p= 0.045 |contact_p= 0.000 |
# [env 2] ep_len=  72 | x_prog= 0.036 | R_mean=-6.656 | fwd= 0.380 | alive=-0.493 | vv_shaping=-0.010 | av_shaping= 0.006 | com= 0.491 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.043 | energy_p= 0.043 |contact_p= 0.000 |
# [env 1] ep_len= 109 | x_prog=-0.957 | R_mean=-13.246 | fwd= 0.026 | alive=-0.495 | vv_shaping=-0.004 | av_shaping=-0.010 | com= 0.449 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.042 |contact_p= 8.537 |
# [env 0] ep_len=  83 | x_prog= 0.639 | R_mean=-2.461 | fwd= 3.652 | alive=-0.494 | vv_shaping=-0.006 | av_shaping=-0.006 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.043 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.8     |
# |    ep_rew_mean     | -888     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 4302     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4040     |
# ---------------------------------
# [env 3] ep_len=  76 | x_prog=-0.549 | R_mean=-8.161 | fwd= 0.040 | alive=-0.493 | vv_shaping=-0.015 | av_shaping=-0.027 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.043 |contact_p= 1.499 |
# [env 2] ep_len=  87 | x_prog= 0.001 | R_mean=-14.187 | fwd= 0.614 | alive=-0.494 | vv_shaping=-0.008 | av_shaping=-0.018 | com= 0.490 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.052 | energy_p= 0.043 |contact_p= 8.928 |
# [env 0] ep_len=  90 | x_prog=-0.525 | R_mean=-5.655 | fwd= 0.006 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.009 | com= 0.485 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.043 |contact_p= 0.000 |
# [env 1] ep_len= 114 | x_prog= 0.552 | R_mean=-2.091 | fwd= 2.376 | alive=-0.496 | vv_shaping=-0.003 | av_shaping= 0.006 | com= 0.493 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.043 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.5     |
# |    ep_rew_mean     | -870     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 4298     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4464     |
# ---------------------------------
# [env 3] ep_len=  79 | x_prog=-0.936 | R_mean=-11.975 | fwd= 0.011 | alive=-0.494 | vv_shaping=-0.013 | av_shaping=-0.044 | com= 0.450 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.049 | energy_p= 0.043 |contact_p= 5.464 |
# [env 2] ep_len=  71 | x_prog=-0.107 | R_mean=-24.322 | fwd= 0.221 | alive=-0.493 | vv_shaping=-0.009 | av_shaping=-0.026 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.059 | energy_p= 0.042 |contact_p= 17.369 |
# [env 0] ep_len=  78 | x_prog= 0.014 | R_mean=-6.163 | fwd= 0.358 | alive=-0.494 | vv_shaping=-0.010 | av_shaping=-0.001 | com= 0.482 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.044 |contact_p= 0.000 |
# [env 3] ep_len=  99 | x_prog= 0.632 | R_mean=-2.122 | fwd= 3.015 | alive=-0.495 | vv_shaping=-0.006 | av_shaping= 0.006 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.040 | energy_p= 0.043 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.4     |
# |    ep_rew_mean     | -868     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 4296     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4868     |
# ---------------------------------
# [env 1] ep_len= 112 | x_prog= 0.631 | R_mean=-5.080 | fwd= 2.653 | alive=-0.496 | vv_shaping=-0.004 | av_shaping= 0.006 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.044 |contact_p= 3.188 |
# [env 2] ep_len=  90 | x_prog=-0.727 | R_mean=-5.665 | fwd= 0.044 | alive=-0.494 | vv_shaping=-0.018 | av_shaping=-0.030 | com= 0.479 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.048 | energy_p= 0.042 |contact_p= 0.000 |
# [env 0] ep_len= 104 | x_prog= 0.384 | R_mean=-3.131 | fwd= 1.764 | alive=-0.495 | vv_shaping=-0.001 | av_shaping= 0.004 | com= 0.489 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.041 | energy_p= 0.042 |contact_p= 0.000 |
# [env 3] ep_len=  66 | x_prog=-0.717 | R_mean=-35.331 | fwd= 0.000 | alive=-0.492 | vv_shaping=-0.003 | av_shaping=-0.010 | com= 0.487 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.061 | energy_p= 0.043 |contact_p= 27.633 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84       |
# |    ep_rew_mean     | -872     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 4287     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5132     |
# ---------------------------------
# [env 1] ep_len=  80 | x_prog=-0.635 | R_mean=-9.738 | fwd= 0.081 | alive=-0.494 | vv_shaping=-0.010 | av_shaping=-0.025 | com= 0.481 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.051 | energy_p= 0.041 |contact_p= 3.430 |
# [env 2] ep_len=  87 | x_prog= 0.613 | R_mean=-2.597 | fwd= 3.239 | alive=-0.494 | vv_shaping=-0.004 | av_shaping= 0.003 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.044 |contact_p= 0.000 |
# [env 0] ep_len=  57 | x_prog=-0.476 | R_mean=-10.065 | fwd= 0.012 | alive=-0.491 | vv_shaping=-0.010 | av_shaping=-0.011 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.050 | energy_p= 0.043 |contact_p= 1.185 |
# [env 3] ep_len=  80 | x_prog=-0.535 | R_mean=-17.481 | fwd= 0.009 | alive=-0.494 | vv_shaping=-0.002 | av_shaping=-0.001 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.046 | energy_p= 0.042 |contact_p= 11.140 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.5     |
# |    ep_rew_mean     | -864     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 4275     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5452     |
# ---------------------------------
# [env 1] ep_len=  60 | x_prog=-0.520 | R_mean=-10.385 | fwd= 0.015 | alive=-0.492 | vv_shaping=-0.008 | av_shaping=-0.001 | com= 0.477 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.049 | energy_p= 0.043 |contact_p= 1.950 |
# [env 0] ep_len=  66 | x_prog=-0.508 | R_mean=-8.938 | fwd= 0.027 | alive=-0.492 | vv_shaping=-0.007 | av_shaping=-0.001 | com= 0.483 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.045 | energy_p= 0.043 |contact_p= 1.284 |
# [env 3] ep_len=  66 | x_prog=-0.183 | R_mean=-7.610 | fwd= 0.092 | alive=-0.492 | vv_shaping=-0.013 | av_shaping=-0.018 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.051 | energy_p= 0.044 |contact_p= 0.000 |
# [env 2] ep_len= 101 | x_prog= 0.078 | R_mean=-7.744 | fwd= 0.712 | alive=-0.495 | vv_shaping=-0.005 | av_shaping=-0.017 | com= 0.485 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.036 | energy_p= 0.041 |contact_p= 3.395 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.9     |
# |    ep_rew_mean     | -850     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 4272     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5740     |
# ---------------------------------
# [env 0] ep_len=  71 | x_prog=-0.429 | R_mean=-11.020 | fwd= 0.040 | alive=-0.493 | vv_shaping=-0.014 | av_shaping=-0.023 | com= 0.468 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.051 | energy_p= 0.041 |contact_p= 3.862 |
# [env 1] ep_len= 130 | x_prog=-1.007 | R_mean=-18.742 | fwd= 0.122 | alive=-0.496 | vv_shaping=-0.002 | av_shaping=-0.011 | com= 0.453 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.045 | energy_p= 0.044 |contact_p= 14.872 |
# [env 3] ep_len=  86 | x_prog=-0.816 | R_mean=-10.518 | fwd= 0.035 | alive=-0.494 | vv_shaping=-0.011 | av_shaping=-0.033 | com= 0.478 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.049 | energy_p= 0.040 |contact_p= 4.589 |
# [env 2] ep_len=  96 | x_prog=-0.880 | R_mean=-8.794 | fwd= 0.159 | alive=-0.495 | vv_shaping=-0.011 | av_shaping=-0.017 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.041 | energy_p= 0.043 |contact_p= 3.635 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.6     |
# |    ep_rew_mean     | -872     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 4278     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6124     |
# ---------------------------------
# [env 0] ep_len=  87 | x_prog=-0.852 | R_mean=-5.836 | fwd= 0.028 | alive=-0.494 | vv_shaping=-0.017 | av_shaping=-0.013 | com= 0.490 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.041 | energy_p= 0.042 |contact_p= 0.000 |
# [env 1] ep_len=  84 | x_prog=-0.964 | R_mean=-12.724 | fwd= 0.034 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.008 | com= 0.484 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.049 | energy_p= 0.042 |contact_p= 6.690 |
# [env 3] ep_len=  94 | x_prog= 0.741 | R_mean=-1.771 | fwd= 3.628 | alive=-0.495 | vv_shaping=-0.006 | av_shaping= 0.004 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.041 | energy_p= 0.042 |contact_p= 0.000 |
# [env 0] ep_len=  66 | x_prog=-0.022 | R_mean=-7.439 | fwd= 0.265 | alive=-0.492 | vv_shaping=-0.016 | av_shaping=-0.020 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.052 | energy_p= 0.043 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.6     |
# |    ep_rew_mean     | -855     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 4286     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6516     |
# ---------------------------------
# [env 2] ep_len=  99 | x_prog= 0.254 | R_mean=-3.859 | fwd= 1.274 | alive=-0.495 | vv_shaping=-0.002 | av_shaping=-0.000 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.044 |contact_p= 0.000 |
# [env 1] ep_len=  53 | x_prog=-0.496 | R_mean=-42.453 | fwd= 0.012 | alive=-0.491 | vv_shaping=-0.007 | av_shaping=-0.024 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.064 | energy_p= 0.043 |contact_p= 32.897 |
# [env 3] ep_len=  70 | x_prog=-0.425 | R_mean=-7.390 | fwd= 0.021 | alive=-0.493 | vv_shaping=-0.021 | av_shaping=-0.015 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.048 | energy_p= 0.043 |contact_p= 0.144 |
# [env 0] ep_len=  73 | x_prog= 0.284 | R_mean=-5.067 | fwd= 1.863 | alive=-0.493 | vv_shaping=-0.006 | av_shaping= 0.006 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.041 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.1     |
# |    ep_rew_mean     | -857     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 4285     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6808     |
# ---------------------------------
# [env 1] ep_len=  70 | x_prog= 0.348 | R_mean=-4.848 | fwd= 2.375 | alive=-0.493 | vv_shaping=-0.006 | av_shaping= 0.008 | com= 0.493 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.043 |contact_p= 0.000 |
# [env 2] ep_len= 105 | x_prog=-0.234 | R_mean=-7.955 | fwd= 0.252 | alive=-0.495 | vv_shaping=-0.005 | av_shaping=-0.015 | com= 0.474 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.045 | energy_p= 0.043 |contact_p= 3.315 |
# [env 0] ep_len=  91 | x_prog=-0.930 | R_mean=-14.307 | fwd= 0.017 | alive=-0.495 | vv_shaping=-0.008 | av_shaping=-0.026 | com= 0.475 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.042 |contact_p= 8.686 |
# [env 3] ep_len= 119 | x_prog=-0.086 | R_mean=-4.128 | fwd= 0.175 | alive=-0.496 | vv_shaping=-0.006 | av_shaping= 0.005 | com= 0.475 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.041 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.7     |
# |    ep_rew_mean     | -851     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 4284     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7192     |
# ---------------------------------
# [env 1] ep_len=  95 | x_prog=-1.097 | R_mean=-16.540 | fwd= 0.065 | alive=-0.495 | vv_shaping=-0.000 | av_shaping=-0.005 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.048 | energy_p= 0.041 |contact_p= 11.249 |
# [env 2] ep_len= 108 | x_prog= 0.460 | R_mean=-2.691 | fwd= 2.025 | alive=-0.495 | vv_shaping=-0.007 | av_shaping= 0.001 | com= 0.491 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.034 | energy_p= 0.042 |contact_p= 0.000 |
# [env 1] ep_len=  79 | x_prog= 0.001 | R_mean=-6.331 | fwd= 0.329 | alive=-0.494 | vv_shaping=-0.009 | av_shaping= 0.001 | com= 0.481 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.041 | energy_p= 0.043 |contact_p= 0.226 |
# [env 3] ep_len=  94 | x_prog=-0.972 | R_mean=-7.273 | fwd= 0.006 | alive=-0.495 | vv_shaping=-0.013 | av_shaping=-0.029 | com= 0.483 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.043 | energy_p= 0.042 |contact_p= 1.822 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.2     |
# |    ep_rew_mean     | -847     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 4282     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7568     |
# ---------------------------------
# [env 0] ep_len= 128 | x_prog=-0.917 | R_mean=-11.193 | fwd= 0.023 | alive=-0.496 | vv_shaping=-0.001 | av_shaping=-0.007 | com= 0.472 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.040 | energy_p= 0.044 |contact_p= 7.192 |
# [env 2] ep_len=  94 | x_prog=-0.673 | R_mean=-5.225 | fwd= 0.217 | alive=-0.495 | vv_shaping=-0.014 | av_shaping=-0.010 | com= 0.479 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.040 | energy_p= 0.044 |contact_p= 0.000 |
# [env 1] ep_len=  85 | x_prog= 0.089 | R_mean=-12.193 | fwd= 0.532 | alive=-0.494 | vv_shaping=-0.008 | av_shaping=-0.027 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.041 |contact_p= 6.712 |
# [env 3] ep_len=  75 | x_prog=-0.477 | R_mean=-18.676 | fwd= 0.034 | alive=-0.493 | vv_shaping=-0.005 | av_shaping=-0.003 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.061 | energy_p= 0.043 |contact_p= 11.938 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.7     |
# |    ep_rew_mean     | -858     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 4278     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7868     |
# ---------------------------------
# [env 0] ep_len=  87 | x_prog= 0.800 | R_mean=-17.206 | fwd= 3.918 | alive=-0.494 | vv_shaping=-0.000 | av_shaping=-0.005 | com= 0.483 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.057 | energy_p= 0.043 |contact_p= 15.260 |
# [env 2] ep_len=  74 | x_prog=-0.353 | R_mean=-8.131 | fwd= 0.047 | alive=-0.493 | vv_shaping=-0.013 | av_shaping=-0.017 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.053 | energy_p= 0.042 |contact_p= 1.299 |
# [env 3] ep_len=  79 | x_prog= 0.049 | R_mean=-15.348 | fwd= 0.677 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.006 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.054 | energy_p= 0.043 |contact_p= 9.592 |
# [env 1] ep_len=  83 | x_prog=-0.867 | R_mean=-6.110 | fwd= 0.090 | alive=-0.494 | vv_shaping=-0.020 | av_shaping=-0.027 | com= 0.454 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.041 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.5     |
# |    ep_rew_mean     | -862     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 4279     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8188     |
# ---------------------------------
# [env 0] ep_len=  85 | x_prog= 0.679 | R_mean=-2.243 | fwd= 3.724 | alive=-0.494 | vv_shaping=-0.007 | av_shaping= 0.007 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.043 |contact_p= 0.000 |
# [env 2] ep_len=  88 | x_prog=-0.770 | R_mean=-11.454 | fwd= 0.052 | alive=-0.494 | vv_shaping=-0.005 | av_shaping=-0.018 | com= 0.457 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.052 | energy_p= 0.045 |contact_p= 5.666 |
# [env 3] ep_len=  69 | x_prog=-0.194 | R_mean=-8.478 | fwd= 0.064 | alive=-0.493 | vv_shaping=-0.011 | av_shaping= 0.001 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.051 | energy_p= 0.043 |contact_p= 1.190 |
# [env 0] ep_len=  62 | x_prog=-0.199 | R_mean=-8.179 | fwd= 0.002 | alive=-0.492 | vv_shaping=-0.019 | av_shaping=-0.016 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.044 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.2     |
# |    ep_rew_mean     | -850     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 4283     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8620     |
# ---------------------------------
# [env 1] ep_len= 109 | x_prog= 0.693 | R_mean=-1.725 | fwd= 2.959 | alive=-0.495 | vv_shaping=-0.003 | av_shaping=-0.002 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.042 |contact_p= 0.000 |
# [env 2] ep_len=  61 | x_prog=-0.436 | R_mean=-13.915 | fwd= 0.082 | alive=-0.492 | vv_shaping=-0.017 | av_shaping=-0.052 | com= 0.475 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.052 | energy_p= 0.043 |contact_p= 5.619 |
# [env 3] ep_len=  82 | x_prog=-0.645 | R_mean=-12.867 | fwd= 0.064 | alive=-0.494 | vv_shaping=-0.011 | av_shaping=-0.042 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.045 | energy_p= 0.041 |contact_p= 6.699 |
# [env 0] ep_len=  75 | x_prog=-0.914 | R_mean=-6.832 | fwd= 0.006 | alive=-0.493 | vv_shaping=-0.021 | av_shaping=-0.023 | com= 0.455 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.046 | energy_p= 0.042 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.1     |
# |    ep_rew_mean     | -838     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 4288     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8920     |
# ---------------------------------
# [env 2] ep_len=  71 | x_prog=-0.269 | R_mean=-15.531 | fwd= 0.013 | alive=-0.493 | vv_shaping=-0.017 | av_shaping=-0.049 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.050 | energy_p= 0.043 |contact_p= 8.350 |
# [env 1] ep_len=  78 | x_prog= 0.610 | R_mean=-3.056 | fwd= 3.435 | alive=-0.494 | vv_shaping=-0.004 | av_shaping= 0.009 | com= 0.489 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.038 | energy_p= 0.043 |contact_p= 0.000 |
# [env 2] ep_len=  56 | x_prog=-0.537 | R_mean=-11.688 | fwd= 0.026 | alive=-0.491 | vv_shaping=-0.008 | av_shaping=-0.009 | com= 0.481 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.054 | energy_p= 0.045 |contact_p= 2.661 |
# [env 3] ep_len=  92 | x_prog= 0.402 | R_mean=-3.392 | fwd= 2.127 | alive=-0.495 | vv_shaping=-0.005 | av_shaping= 0.003 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.042 | energy_p= 0.042 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.5     |
# |    ep_rew_mean     | -824     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 4286     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9156     |
# ---------------------------------
# [env 0] ep_len=  74 | x_prog=-0.329 | R_mean=-19.237 | fwd= 0.150 | alive=-0.493 | vv_shaping=-0.006 | av_shaping=-0.020 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.055 | energy_p= 0.042 |contact_p= 12.508 |
# [env 1] ep_len=  99 | x_prog= 0.476 | R_mean=-2.910 | fwd= 2.223 | alive=-0.495 | vv_shaping=-0.003 | av_shaping=-0.001 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.038 | energy_p= 0.042 |contact_p= 0.000 |
# [env 3] ep_len=  66 | x_prog=-0.385 | R_mean=-18.137 | fwd= 0.155 | alive=-0.492 | vv_shaping=-0.008 | av_shaping=-0.022 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.058 | energy_p= 0.043 |contact_p= 10.590 |
# [env 0] ep_len=  76 | x_prog=-0.622 | R_mean=-15.929 | fwd= 0.024 | alive=-0.493 | vv_shaping=-0.007 | av_shaping=-0.029 | com= 0.479 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.057 | energy_p= 0.043 |contact_p= 9.223 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.5     |
# |    ep_rew_mean     | -828     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 4281     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9520     |
# ---------------------------------
# [env 2] ep_len=  99 | x_prog=-0.816 | R_mean=-9.040 | fwd= 0.147 | alive=-0.495 | vv_shaping=-0.008 | av_shaping=-0.019 | com= 0.455 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.042 |contact_p= 3.982 |
# [env 1] ep_len=  88 | x_prog=-1.026 | R_mean=-8.890 | fwd= 0.019 | alive=-0.494 | vv_shaping=-0.014 | av_shaping=-0.034 | com= 0.463 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.046 | energy_p= 0.042 |contact_p= 3.060 |
# [env 3] ep_len=  82 | x_prog= 0.327 | R_mean=-4.298 | fwd= 1.888 | alive=-0.494 | vv_shaping=-0.004 | av_shaping=-0.005 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.041 | energy_p= 0.043 |contact_p= 0.000 |
# [env 0] ep_len=  72 | x_prog=-0.007 | R_mean=-6.691 | fwd= 0.372 | alive=-0.493 | vv_shaping=-0.012 | av_shaping=-0.018 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.043 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.7     |
# |    ep_rew_mean     | -820     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 4280     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9808     |
# ---------------------------------
# [env 2] ep_len= 128 | x_prog= 0.490 | R_mean=-6.994 | fwd= 1.700 | alive=-0.496 | vv_shaping=-0.000 | av_shaping=-0.007 | com= 0.472 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.038 | energy_p= 0.051 |contact_p= 4.667 |
# [env 1] ep_len= 101 | x_prog=-1.014 | R_mean=-5.222 | fwd= 0.022 | alive=-0.495 | vv_shaping=-0.013 | av_shaping=-0.000 | com= 0.458 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.044 | energy_p= 0.061 |contact_p= 0.138 |
# [env 0] ep_len=  73 | x_prog=-0.622 | R_mean=-6.948 | fwd= 0.050 | alive=-0.493 | vv_shaping=-0.015 | av_shaping=-0.006 | com= 0.483 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.048 | energy_p= 0.070 |contact_p= 0.000 |
# [env 3] ep_len= 113 | x_prog=-1.145 | R_mean=-12.183 | fwd= 0.090 | alive=-0.496 | vv_shaping=-0.000 | av_shaping=-0.012 | com= 0.476 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.047 | energy_p= 0.076 |contact_p= 7.693 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85       |
# |    ep_rew_mean     | -814     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 3169     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 10200    |
# | train/             |          |
# |    actor_loss      | 131      |
# |    critic_loss     | 6.96e+03 |
# |    ent_coef        | 0.0109   |
# |    ent_coef_loss   | 410      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 247549   |
# ---------------------------------
# [env 0] ep_len= 110 | x_prog= 0.502 | R_mean=-2.492 | fwd= 2.210 | alive=-0.495 | vv_shaping=-0.012 | av_shaping=-0.008 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.103 |contact_p= 0.000 |
# [env 1] ep_len= 123 | x_prog= 0.353 | R_mean=-4.396 | fwd= 1.552 | alive=-0.496 | vv_shaping=-0.011 | av_shaping=-0.012 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.035 | energy_p= 0.104 |contact_p= 1.724 |
# [env 2] ep_len= 137 | x_prog=-0.044 | R_mean=-5.859 | fwd= 0.711 | alive=-0.496 | vv_shaping=-0.004 | av_shaping=-0.008 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.033 | energy_p= 0.110 |contact_p= 2.763 |
# [env 3] ep_len= 113 | x_prog=-0.035 | R_mean=-7.693 | fwd= 0.250 | alive=-0.496 | vv_shaping=-0.011 | av_shaping=-0.016 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.103 |contact_p= 3.353 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.5     |
# |    ep_rew_mean     | -804     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 2306     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 10652    |
# | train/             |          |
# |    actor_loss      | 106      |
# |    critic_loss     | 3.32e+03 |
# |    ent_coef        | 0.0122   |
# |    ent_coef_loss   | 351      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 247662   |
# ---------------------------------
# [env 1] ep_len= 124 | x_prog=-1.154 | R_mean=-4.163 | fwd= 0.053 | alive=-0.496 | vv_shaping=-0.010 | av_shaping=-0.005 | com= 0.467 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.038 | energy_p= 0.102 |contact_p= 0.000 |
# [env 0] ep_len= 152 | x_prog=-1.147 | R_mean=-7.614 | fwd= 0.055 | alive=-0.497 | vv_shaping=-0.007 | av_shaping=-0.009 | com= 0.476 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.035 | energy_p= 0.099 |contact_p= 4.209 |
# [env 3] ep_len= 127 | x_prog=-1.008 | R_mean=-9.962 | fwd= 0.112 | alive=-0.496 | vv_shaping=-0.004 | av_shaping=-0.008 | com= 0.477 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.099 |contact_p= 5.968 |
# [env 2] ep_len= 183 | x_prog= 0.334 | R_mean=-5.704 | fwd= 1.175 | alive=-0.497 | vv_shaping=-0.005 | av_shaping= 0.002 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.032 | energy_p= 0.096 |contact_p= 4.003 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.9     |
# |    ep_rew_mean     | -811     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 1673     |
# |    time_elapsed    | 6        |
# |    total_timesteps | 11336    |
# | train/             |          |
# |    actor_loss      | 102      |
# |    critic_loss     | 1.4e+03  |
# |    ent_coef        | 0.0135   |
# |    ent_coef_loss   | 306      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 247833   |
# ---------------------------------
# [env 1] ep_len= 105 | x_prog=-0.945 | R_mean=-4.807 | fwd= 0.123 | alive=-0.495 | vv_shaping=-0.011 | av_shaping=-0.004 | com= 0.478 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.037 | energy_p= 0.098 |contact_p= 0.000 |
# [env 0] ep_len= 103 | x_prog=-0.855 | R_mean=-4.858 | fwd= 0.142 | alive=-0.495 | vv_shaping=-0.012 | av_shaping= 0.002 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.096 |contact_p= 0.000 |
# [env 3] ep_len= 107 | x_prog=-0.841 | R_mean=-4.708 | fwd= 0.138 | alive=-0.495 | vv_shaping=-0.011 | av_shaping=-0.001 | com= 0.469 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.038 | energy_p= 0.096 |contact_p= 0.000 |
# [env 2] ep_len= 134 | x_prog=-1.051 | R_mean=-3.679 | fwd= 0.205 | alive=-0.496 | vv_shaping=-0.008 | av_shaping= 0.001 | com= 0.478 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.031 | energy_p= 0.097 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.2     |
# |    ep_rew_mean     | -798     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 1397     |
# |    time_elapsed    | 8        |
# |    total_timesteps | 11872    |
# | train/             |          |
# |    actor_loss      | 108      |
# |    critic_loss     | 607      |
# |    ent_coef        | 0.0143   |
# |    ent_coef_loss   | 278      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 247967   |
# ---------------------------------
# [env 1] ep_len= 127 | x_prog=-1.103 | R_mean=-3.853 | fwd= 0.229 | alive=-0.496 | vv_shaping=-0.009 | av_shaping= 0.002 | com= 0.486 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.033 | energy_p= 0.095 |contact_p= 0.000 |
# [env 0] ep_len= 114 | x_prog=-1.006 | R_mean=-4.371 | fwd= 0.185 | alive=-0.496 | vv_shaping=-0.011 | av_shaping=-0.001 | com= 0.469 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.035 | energy_p= 0.096 |contact_p= 0.000 |
# [env 3] ep_len= 215 | x_prog=-1.152 | R_mean=-2.291 | fwd= 0.162 | alive=-0.498 | vv_shaping=-0.003 | av_shaping=-0.002 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.030 | energy_p= 0.093 |contact_p= 0.000 |
# [env 2] ep_len= 163 | x_prog=-1.177 | R_mean=-3.009 | fwd= 0.194 | alive=-0.497 | vv_shaping=-0.006 | av_shaping=-0.003 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.032 | energy_p= 0.095 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.6     |
# |    ep_rew_mean     | -777     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 1185     |
# |    time_elapsed    | 10       |
# |    total_timesteps | 12524    |
# | train/             |          |
# |    actor_loss      | 78.7     |
# |    critic_loss     | 647      |
# |    ent_coef        | 0.0152   |
# |    ent_coef_loss   | 230      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 248130   |
# ---------------------------------
# [env 0] ep_len= 170 | x_prog=-1.131 | R_mean=-5.075 | fwd= 0.259 | alive=-0.497 | vv_shaping=-0.001 | av_shaping= 0.003 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.040 | energy_p= 0.096 |contact_p= 2.253 |
# [env 1] ep_len= 196 | x_prog=-1.295 | R_mean=-3.973 | fwd= 0.221 | alive=-0.497 | vv_shaping=-0.003 | av_shaping= 0.001 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.033 | energy_p= 0.094 |contact_p= 1.516 |
# [env 3] ep_len= 149 | x_prog=-1.060 | R_mean=-3.873 | fwd= 0.154 | alive=-0.497 | vv_shaping=-0.008 | av_shaping=-0.001 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.032 | energy_p= 0.093 |contact_p= 0.538 |
# [env 0] ep_len= 143 | x_prog=-1.158 | R_mean=-4.150 | fwd= 0.172 | alive=-0.497 | vv_shaping=-0.007 | av_shaping=-0.002 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.034 | energy_p= 0.096 |contact_p= 0.685 |
# [env 2] ep_len= 186 | x_prog=-1.099 | R_mean=-2.665 | fwd= 0.159 | alive=-0.497 | vv_shaping=-0.006 | av_shaping=-0.005 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.033 | energy_p= 0.094 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.5     |
# |    ep_rew_mean     | -770     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 1033     |
# |    time_elapsed    | 12       |
# |    total_timesteps | 13268    |
# | train/             |          |
# |    actor_loss      | 101      |
# |    critic_loss     | 956      |
# |    ent_coef        | 0.0161   |
# |    ent_coef_loss   | 208      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 248316   |
# ---------------------------------
# [env 3] ep_len= 137 | x_prog=-1.077 | R_mean=-3.809 | fwd= 0.167 | alive=-0.496 | vv_shaping=-0.008 | av_shaping=-0.002 | com= 0.493 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.033 | energy_p= 0.096 |contact_p= 0.183 |
# [env 1] ep_len= 221 | x_prog= 1.095 | R_mean=-0.557 | fwd= 1.826 | alive=-0.498 | vv_shaping=-0.006 | av_shaping=-0.003 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.017 | energy_p= 0.096 |contact_p= 0.000 |
# [env 2] ep_len= 112 | x_prog=-1.020 | R_mean=-4.939 | fwd= 0.169 | alive=-0.496 | vv_shaping=-0.013 | av_shaping=-0.008 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.039 | energy_p= 0.093 |contact_p= 0.487 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.4     |
# |    ep_rew_mean     | -748     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 968      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 13716    |
# | train/             |          |
# |    actor_loss      | 117      |
# |    critic_loss     | 1.28e+03 |
# |    ent_coef        | 0.0167   |
# |    ent_coef_loss   | 219      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 248428   |
# ---------------------------------
# [env 0] ep_len= 148 | x_prog=-0.908 | R_mean=-4.276 | fwd= 0.149 | alive=-0.497 | vv_shaping=-0.006 | av_shaping=-0.001 | com= 0.490 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.040 | energy_p= 0.095 |contact_p= 0.896 |
# [env 3] ep_len= 118 | x_prog=-0.943 | R_mean=-4.455 | fwd= 0.175 | alive=-0.496 | vv_shaping=-0.010 | av_shaping=-0.001 | com= 0.492 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.030 | energy_p= 0.099 |contact_p= 0.250 |
# [env 1] ep_len= 126 | x_prog=-1.176 | R_mean=-7.992 | fwd= 0.150 | alive=-0.496 | vv_shaping=-0.007 | av_shaping=-0.004 | com= 0.480 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.034 | energy_p= 0.094 |contact_p= 4.018 |
# [env 2] ep_len= 127 | x_prog=-0.962 | R_mean=-4.682 | fwd= 0.169 | alive=-0.496 | vv_shaping=-0.009 | av_shaping=-0.002 | com= 0.490 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.036 | energy_p= 0.095 |contact_p= 0.766 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -749     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 909      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 14224    |
# | train/             |          |
# |    actor_loss      | 89.3     |
# |    critic_loss     | 504      |
# |    ent_coef        | 0.0173   |
# |    ent_coef_loss   | 179      |
# |    learning_rate   | 0.000298 |
# |    n_updates       | 248555   |
# ---------------------------------
# [env 0] ep_len= 118 | x_prog=-0.954 | R_mean=-4.212 | fwd= 0.179 | alive=-0.496 | vv_shaping=-0.011 | av_shaping=-0.006 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.033 | energy_p= 0.102 |contact_p= 0.000 |
# [env 3] ep_len= 109 | x_prog=-1.073 | R_mean=-4.584 | fwd= 0.154 | alive=-0.495 | vv_shaping=-0.011 | av_shaping=-0.006 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.040 | energy_p= 0.096 |contact_p= 0.000 |
# [env 2] ep_len= 114 | x_prog=-1.121 | R_mean=-4.348 | fwd= 0.188 | alive=-0.496 | vv_shaping=-0.012 | av_shaping=-0.002 | com= 0.493 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.036 | energy_p= 0.097 |contact_p= 0.000 |
# ...
# [🎥] Saved video at episode 1200 → humanoid_custom_videos\ep_1200
# [env 3] ep_len=2000 | x_prog= 0.104 | R_mean= 0.081 | fwd= 0.170 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.020 | energy_p= 0.071 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 716      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 338      |
# |    time_elapsed    | 1147     |
# |    total_timesteps | 388780   |
# | train/             |          |
# |    actor_loss      | 107      |
# |    critic_loss     | 138      |
# |    ent_coef        | 0.0174   |
# |    ent_coef_loss   | -1.64    |
# |    learning_rate   | 0.000242 |
# |    n_updates       | 342194   |
# ---------------------------------
# [env 3] ep_len= 316 | x_prog= 1.043 | R_mean=-0.092 | fwd= 1.594 | alive=-0.498 | vv_shaping=-0.003 | av_shaping= 0.002 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.023 | energy_p= 0.078 |contact_p= 0.000 |
# [env 3] ep_len= 217 | x_prog= 1.198 | R_mean=-0.118 | fwd= 2.303 | alive=-0.498 | vv_shaping=-0.006 | av_shaping=-0.001 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.030 | energy_p= 0.081 |contact_p= 0.000 |
# [env 0] ep_len=1945 | x_prog= 1.175 | R_mean= 0.116 | fwd= 0.465 | alive=-0.500 | vv_shaping=-0.000 | av_shaping= 0.003 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.021 | energy_p= 0.073 |contact_p= 0.000 |
# [env 0] ep_len= 335 | x_prog= 1.077 | R_mean=-0.237 | fwd= 1.366 | alive=-0.499 | vv_shaping=-0.003 | av_shaping=-0.000 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.029 | energy_p= 0.078 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 676      |
# |    ep_rew_mean     | -88.6    |
# | time/              |          |
# |    episodes        | 1204     |
# |    fps             | 338      |
# |    time_elapsed    | 1159     |
# |    total_timesteps | 392976   |
# | train/             |          |
# |    actor_loss      | 85.2     |
# |    critic_loss     | 127      |
# |    ent_coef        | 0.0176   |
# |    ent_coef_loss   | -0.0765  |
# |    learning_rate   | 0.000241 |
# |    n_updates       | 343243   |
# ---------------------------------
# [env 2] ep_len=1533 | x_prog= 0.936 | R_mean= 0.185 | fwd= 0.606 | alive=-0.500 | vv_shaping=-0.001 | av_shaping= 0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.022 | energy_p= 0.075 |contact_p= 0.000 |
# [env 0] ep_len= 670 | x_prog= 1.102 | R_mean= 0.067 | fwd= 0.911 | alive=-0.499 | vv_shaping=-0.002 | av_shaping= 0.002 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.022 | energy_p= 0.076 |contact_p= 0.000 |
# [env 1] ep_len=2000 | x_prog= 0.096 | R_mean= 0.128 | fwd= 0.218 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.003 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.019 | energy_p= 0.073 |contact_p= 0.000 |
# [env 0] ep_len= 228 | x_prog=-0.828 | R_mean=-1.994 | fwd= 0.328 | alive=-0.498 | vv_shaping=-0.003 | av_shaping=-0.006 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.033 | energy_p= 0.083 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 670      |
# |    ep_rew_mean     | -89.9    |
# | time/              |          |
# |    episodes        | 1208     |
# |    fps             | 338      |
# |    time_elapsed    | 1170     |
# |    total_timesteps | 396568   |
# | train/             |          |
# |    actor_loss      | 82.1     |
# |    critic_loss     | 67.4     |
# |    ent_coef        | 0.0171   |
# |    ent_coef_loss   | -4.33    |
# |    learning_rate   | 0.000241 |
# |    n_updates       | 344141   |
# ---------------------------------
# [env 1] ep_len= 186 | x_prog= 1.096 | R_mean=-0.355 | fwd= 2.450 | alive=-0.497 | vv_shaping=-0.004 | av_shaping= 0.000 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.029 | energy_p= 0.082 |contact_p= 0.000 |
# [env 3] ep_len=2000 | x_prog= 0.205 | R_mean= 0.216 | fwd= 0.309 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.003 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.022 | energy_p= 0.074 |contact_p= 0.000 |
# [env 0] ep_len=1021 | x_prog=-0.426 | R_mean=-0.286 | fwd= 0.303 | alive=-0.500 | vv_shaping=-0.001 | av_shaping= 0.000 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.023 | energy_p= 0.077 |contact_p= 0.000 |
# [env 2] ep_len=2000 | x_prog= 0.095 | R_mean= 0.148 | fwd= 0.239 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.003 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.020 | energy_p= 0.074 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 673      |
# |    ep_rew_mean     | -75.2    |
# | time/              |          |
# |    episodes        | 1212     |
# |    fps             | 338      |
# |    time_elapsed    | 1189     |
# |    total_timesteps | 402600   |
# | train/             |          |
# |    actor_loss      | 89.8     |
# |    critic_loss     | 100      |
# |    ent_coef        | 0.0171   |
# |    ent_coef_loss   | 2.77     |
# |    learning_rate   | 0.00024  |
# |    n_updates       | 345649   |
# ---------------------------------
# [env 1] ep_len=2000 | x_prog= 0.097 | R_mean= 0.164 | fwd= 0.256 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.003 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.021 | energy_p= 0.073 |contact_p= 0.000 |
# [env 1] ep_len= 304 | x_prog= 1.001 | R_mean=-0.387 | fwd= 1.372 | alive=-0.498 | vv_shaping=-0.004 | av_shaping=-0.003 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.029 | energy_p= 0.078 |contact_p= 0.000 |
# [env 3] ep_len=2000 | x_prog= 0.264 | R_mean= 0.233 | fwd= 0.326 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.003 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.021 | energy_p= 0.075 |contact_p= 0.000 |
# [env 0] ep_len=1633 | x_prog=-0.644 | R_mean=-0.109 | fwd= 0.333 | alive=-0.500 | vv_shaping=-0.000 | av_shaping= 0.003 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.022 | energy_p= 0.078 |contact_p= 0.038 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 681      |
# |    ep_rew_mean     | -66      |
# | time/              |          |
# |    episodes        | 1216     |
# |    fps             | 338      |
# |    time_elapsed    | 1202     |
# |    total_timesteps | 407184   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 115      |
# |    ent_coef        | 0.0176   |
# |    ent_coef_loss   | -0.249   |
# |    learning_rate   | 0.000239 |
# |    n_updates       | 346795   |
# ---------------------------------
# [env 3] ep_len= 165 | x_prog= 0.929 | R_mean=-0.504 | fwd= 2.650 | alive=-0.497 | vv_shaping=-0.007 | av_shaping= 0.004 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.038 | energy_p= 0.084 |contact_p= 0.000 |
# [env 2] ep_len=2000 | x_prog= 0.189 | R_mean= 0.196 | fwd= 0.288 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.003 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.020 | energy_p= 0.075 |contact_p= 0.000 |
# [env 2] ep_len=  93 | x_prog=-0.880 | R_mean=-5.228 | fwd= 0.335 | alive=-0.495 | vv_shaping=-0.008 | av_shaping=-0.011 | com= 0.461 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.041 | energy_p= 0.093 |contact_p= 0.000 |
# [env 2] ep_len= 134 | x_prog= 1.095 | R_mean=-0.539 | fwd= 3.317 | alive=-0.496 | vv_shaping=-0.009 | av_shaping= 0.001 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.036 | energy_p= 0.082 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 662      |
# |    ep_rew_mean     | -70.3    |
# | time/              |          |
# |    episodes        | 1220     |
# |    fps             | 338      |
# |    time_elapsed    | 1215     |
# |    total_timesteps | 411508   |
# | train/             |          |
# |    actor_loss      | 88.2     |
# |    critic_loss     | 62.7     |
# |    ent_coef        | 0.0167   |
# |    ent_coef_loss   | -2.43    |
# |    learning_rate   | 0.000238 |
# |    n_updates       | 347876   |
# ---------------------------------
# [env 1] ep_len=2000 | x_prog= 0.202 | R_mean= 0.158 | fwd= 0.246 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.017 | energy_p= 0.074 |contact_p= 0.000 |
# [env 1] ep_len= 170 | x_prog= 1.214 | R_mean=-0.109 | fwd= 2.953 | alive=-0.497 | vv_shaping=-0.006 | av_shaping= 0.000 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.032 | energy_p= 0.082 |contact_p= 0.000 |
# [env 0] ep_len=2000 | x_prog= 0.118 | R_mean= 0.115 | fwd= 0.202 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.016 | energy_p= 0.073 |contact_p= 0.000 |
# [env 1] ep_len= 152 | x_prog= 1.090 | R_mean=-0.362 | fwd= 3.055 | alive=-0.497 | vv_shaping=-0.008 | av_shaping= 0.001 | com= 0.494 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.034 | energy_p= 0.083 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 665      |
# |    ep_rew_mean     | -68.4    |
# | time/              |          |
# |    episodes        | 1224     |
# |    fps             | 338      |
# |    time_elapsed    | 1227     |
# |    total_timesteps | 415540   |
# | train/             |          |
# |    actor_loss      | 106      |
# |    critic_loss     | 119      |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | 6.79     |
# |    learning_rate   | 0.000238 |
# |    n_updates       | 348884   |
# ---------------------------------
# [env 3] ep_len=2000 | x_prog= 0.136 | R_mean= 0.095 | fwd= 0.179 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.014 | energy_p= 0.073 |contact_p= 0.000 |
# [env 0] ep_len= 134 | x_prog= 1.234 | R_mean=-0.361 | fwd= 3.500 | alive=-0.496 | vv_shaping=-0.010 | av_shaping=-0.002 | com= 0.495 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.033 | energy_p= 0.084 |contact_p= 0.000 |
# [env 1] ep_len= 276 | x_prog= 1.175 | R_mean=-0.266 | fwd= 1.658 | alive=-0.498 | vv_shaping=-0.005 | av_shaping=-0.001 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.027 | energy_p= 0.080 |contact_p= 0.000 |
# [env 2] ep_len=2000 | x_prog= 0.146 | R_mean= 0.053 | fwd= 0.137 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.001 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.013 | energy_p= 0.073 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 692      |
# |    ep_rew_mean     | -65.5    |
# | time/              |          |
# |    episodes        | 1228     |
# |    fps             | 338      |
# |    time_elapsed    | 1239     |
# |    total_timesteps | 419508   |
# | train/             |          |
# |    actor_loss      | 85.7     |
# |    critic_loss     | 40.4     |
# |    ent_coef        | 0.0172   |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.000237 |
# |    n_updates       | 349876   |
# ---------------------------------
# [env 2] ep_len= 224 | x_prog= 1.097 | R_mean=-0.269 | fwd= 2.069 | alive=-0.498 | vv_shaping=-0.006 | av_shaping= 0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.024 | energy_p= 0.081 |contact_p= 0.000 |
# [env 2] ep_len= 135 | x_prog= 0.978 | R_mean=-0.688 | fwd= 3.137 | alive=-0.496 | vv_shaping=-0.008 | av_shaping= 0.002 | com= 0.496 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.035 | energy_p= 0.080 |contact_p= 0.000 |
# [env 3] ep_len=1371 | x_prog= 0.982 | R_mean= 0.006 | fwd= 0.463 | alive=-0.500 | vv_shaping=-0.001 | av_shaping= 0.001 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.020 | energy_p= 0.073 |contact_p= 0.000 |
# [env 2] ep_len= 313 | x_prog= 1.042 | R_mean=-0.340 | fwd= 1.362 | alive=-0.498 | vv_shaping=-0.004 | av_shaping= 0.001 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.023 | energy_p= 0.080 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 693      |
# |    ep_rew_mean     | -60.8    |
# | time/              |          |
# |    episodes        | 1232     |
# |    fps             | 338      |
# |    time_elapsed    | 1247     |
# |    total_timesteps | 422196   |
# | train/             |          |
# |    actor_loss      | 97.1     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.0174   |
# |    ent_coef_loss   | 5.06     |
# |    learning_rate   | 0.000237 |
# |    n_updates       | 350548   |
# ---------------------------------
# [env 3] ep_len= 490 | x_prog= 1.066 | R_mean=-0.147 | fwd= 0.973 | alive=-0.499 | vv_shaping=-0.002 | av_shaping= 0.002 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.021 | energy_p= 0.078 |contact_p= 0.000 |
# [env 2] ep_len= 209 | x_prog= 1.059 | R_mean=-0.464 | fwd= 2.049 | alive=-0.498 | vv_shaping=-0.006 | av_shaping=-0.001 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.032 | energy_p= 0.082 |contact_p= 0.000 |
# [env 0] ep_len=2000 | x_prog= 0.162 | R_mean= 0.076 | fwd= 0.163 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.015 | energy_p= 0.074 |contact_p= 0.000 |
# [env 3] ep_len= 176 | x_prog= 0.906 | R_mean=-0.599 | fwd= 2.366 | alive=-0.497 | vv_shaping=-0.007 | av_shaping=-0.003 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.032 | energy_p= 0.084 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 712      |
# |    ep_rew_mean     | -49.9    |
# | time/              |          |
# |    episodes        | 1236     |
# |    fps             | 338      |
# |    time_elapsed    | 1252     |
# |    total_timesteps | 423720   |
# | train/             |          |
# |    actor_loss      | 113      |
# |    critic_loss     | 97.8     |
# |    ent_coef        | 0.0177   |
# |    ent_coef_loss   | 6.67     |
# |    learning_rate   | 0.000236 |
# |    n_updates       | 350929   |
# ---------------------------------
# [env 2] ep_len= 358 | x_prog= 1.022 | R_mean=-0.230 | fwd= 1.272 | alive=-0.499 | vv_shaping=-0.003 | av_shaping= 0.003 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.024 | energy_p= 0.082 |contact_p= 0.000 |
# [env 1] ep_len=2000 | x_prog= 0.223 | R_mean= 0.109 | fwd= 0.196 | alive=-0.500 | vv_shaping= 0.000 | av_shaping= 0.002 | com= 0.500 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.015 | energy_p= 0.074 |contact_p= 0.000 |
# [env 0] ep_len= 286 | x_prog= 1.164 | R_mean=-0.285 | fwd= 1.572 | alive=-0.498 | vv_shaping=-0.004 | av_shaping= 0.000 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.025 | energy_p= 0.081 |contact_p= 0.000 |
# [env 3] ep_len= 312 | x_prog= 1.046 | R_mean=-0.232 | fwd= 1.476 | alive=-0.498 | vv_shaping=-0.004 | av_shaping= 0.001 | com= 0.498 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.023 | energy_p= 0.079 |contact_p= 0.000 |
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 717      |
# |    ep_rew_mean     | -37.6    |
# | time/              |          |
# |    episodes        | 1240     |
# |    fps             | 338      |
# |    time_elapsed    | 1256     |
# |    total_timesteps | 424968   |
# | train/             |          |
# |    actor_loss      | 93       |
# |    critic_loss     | 59.1     |
# |    ent_coef        | 0.0175   |
# |    ent_coef_loss   | -0.791   |
# |    learning_rate   | 0.000236 |
# |    n_updates       | 351241   |
# ---------------------------------
# [env 2] ep_len= 207 | x_prog= 1.031 | R_mean=-0.347 | fwd= 2.180 | alive=-0.498 | vv_shaping=-0.005 | av_shaping= 0.004 | com= 0.497 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.029 | energy_p= 0.079 |contact_p= 0.000 |
# [env 0] ep_len= 188 | x_prog= 1.094 | R_mean=-0.348 | fwd= 2.426 | alive=-0.497 | vv_shaping=-0.006 | av_shaping=-0.001 | com= 0.499 | upright= 0.000 | lat_p= 0.000 | accel_p= 0.028 | energy_p= 0.080 |contact_p= 0.000 |

# %%
#Generate More Video Samples
######
from humanoid_variants import VARIANTS
cfg = VARIANTS["test_var"]

model = SAC.load("humanoid_custom_sac.zip")

hm.record_policy_video(
    model, 
    variant_name="humanoid_custom", 
    cfg=cfg, 
    video_dir="test_videos", 
    num_episodes=3
)


######
# Out:
# calculated base height: 1.0799999999999998
# [video] Loaded VecNormalize stats from ./norms/humanoid_custom_vecnorm.pkl
# Saved videos to: test_videos

# %%
#Collect trajectories
from humanoid_module import VARIANTS
cfg = VARIANTS["default_var"]

model = PPO.load("humanoid_default_ppo.zip")
hm.collect_trajectories(
        model=model,
        variant_name="humanoid_default",
        cfg=cfg,
        num_episodes=20
    )
# Out:
# Saved: humanoid_default_traj.npz

# %%
#build diffusion
import numpy as np
import torch
from torch.utils.data import DataLoader
from diffusion import HumanoidDiffusionDataset, PoseDiffusion, morph_vector_from_params
from humanoid_module import VARIANTS

def build_diffusion_dataset(traj_files, past_len=10, future_len=10):
    episodes = []
    for name, cfg in VARIANTS.items():
        file = f"{name}_traj.npz"
        if file not in traj_files:
            continue
        data = np.load(file)
        qpos = data["qpos"]  # [T, D_q]
        morph_vec = morph_vector_from_params(cfg)  # uses MORPH_KEYS in diffusion.py
        episodes.append({"qpos": qpos, "morph": morph_vec})

    dataset = HumanoidDiffusionDataset(
        episodes=episodes,
        past_len=past_len,
        future_len=future_len
    )
    return dataset

traj_files = [f"{name}_traj.npz" for name in VARIANTS.keys()]
dataset = build_diffusion_dataset(traj_files, past_len=10, future_len=10)
loader = DataLoader(dataset, batch_size=64, shuffle=True)

# %%
#Train diffusion

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

diffusion_model = PoseDiffusion(
    D_target=dataset.D_target,
    D_cond=dataset.D_cond,
    n_steps=100,
    hidden=512
).to(device)

opt = torch.optim.Adam(diffusion_model.parameters(), lr=1e-4)

def train_diffusion(num_epochs=20):
    diffusion_model.train()
    for epoch in range(num_epochs):
        total_loss = 0.0
        for x_0, cond in loader:
            x_0 = x_0.to(device)      # future pose chunk flattened
            cond = cond.to(device)    # past poses + morphology

            B = x_0.size(0)
            t = torch.randint(
                0, diffusion_model.n_steps,
                (B,), device=device, dtype=torch.long
            )
            noise = torch.randn_like(x_0)
            x_t = diffusion_model.q_sample(x_0, t, noise=noise)

            eps_pred = diffusion_model(x_t, t, cond)
            loss = torch.mean((eps_pred - noise) ** 2)

            opt.zero_grad()
            loss.backward()
            opt.step()

            total_loss += loss.item() * B

        print(f"Epoch {epoch+1}: loss = {total_loss / len(dataset):.6f}")

    torch.save(diffusion_model.state_dict(), "pose_diffusion.pt")

train_diffusion()
